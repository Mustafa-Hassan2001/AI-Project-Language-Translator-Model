# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("eng_-french.csv")

# %%
data.head()
# Out:
#   English words/sentences French words/sentences
# 0                     Hi.                 Salut!
# 1                    Run!                Cours !
# 2                    Run!               Courez !
# 3                    Who?                  Qui ?
# 4                    Wow!             Ça alors !

# %%
data['English words/sentences count'] = data['English words/sentences'].str.split().str.len()

# %%
data['French words/sentences count'] = data['French words/sentences'].str.split().str.len()

# %%
data.head()
# Out:
#   English words/sentences French words/sentences  \
# 0                     Hi.                 Salut!
# 1                    Run!                Cours !
# 2                    Run!               Courez !
# 3                    Who?                  Qui ?
# 4                    Wow!             Ça alors !
#
#    English words/sentences count  French words/sentences count
# 0                              1                             1
# 1                              1                             2
# 2                              1                             2
# 3                              1                             2
# 4                              1                             3

# %%
data = data[(data['English words/sentences count']<6)&(data['French words/sentences count']<6)]

# %%
data.head()
# Out:
#   English words/sentences French words/sentences  \
# 0                     Hi.                 Salut!
# 1                    Run!                Cours !
# 2                    Run!               Courez !
# 3                    Who?                  Qui ?
# 4                    Wow!             Ça alors !
#
#    English words/sentences count  French words/sentences count
# 0                              1                             1
# 1                              1                             2
# 2                              1                             2
# 3                              1                             2
# 4                              1                             3

# %%
data = data.drop_duplicates()
data.head()
# Out:
#   English words/sentences French words/sentences  \
# 0                     Hi.                 Salut!
# 1                    Run!                Cours !
# 2                    Run!               Courez !
# 3                    Who?                  Qui ?
# 4                    Wow!             Ça alors !
#
#    English words/sentences count  French words/sentences count
# 0                              1                             1
# 1                              1                             2
# 2                              1                             2
# 3                              1                             2
# 4                              1                             3

# %% [markdown]
# # **Dividing Data Into Train Test Vaildate**

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.2)

# %%
train["English words/sentences count"].max()
# Out:
# 5

# %%
train["French words/sentences count"].max()
# Out:
# 5

# %%
train, valid = train_test_split(data, test_size=0.2)

# %% [markdown]
# # **Word Frequency**

# %%
freq_x = train['English words/sentences'].str.split(expand=True).stack().value_counts().reset_index()
freq_y = train['French words/sentences'].str.split(expand=True).stack().value_counts().reset_index()

freq_x.to_csv('English_freq.csv', index=False)
freq_y.to_csv('French_freq.csv', index=False)

# %%
freq_x = pd.read_csv('English_freq.csv')
freq_y = pd.read_csv('French_freq.csv')

# %%
freq_x.head()
# Out:
#   index  count
# 0     I   7497
# 1     a   4206
# 2   you   4145
# 3    is   3664
# 4   the   2848

# %%
freq_y.head()
# Out:
#   index  count
# 0     ?   6395
# 1    Je   5737
# 2   est   2912
# 3    Il   2807
# 4   pas   2709

# %% [markdown]
# # **Data Preaparation / PreProcessing**

# %%
def get_data(raw_lines) :
  text=[]
  for raw_line in raw_lines:
    text.append('<start>' + raw_line + '<end>')
  return text

# %%
english_train = get_data(list(train['English words/sentences']))

# %%
english_train
# Out:
# ['<start>It was raining.<end>',
#  '<start>Tom certainly enjoys his wine.<end>',
#  '<start>He interpreted for me.<end>',
#  '<start>I messed up.<end>',
#  "<start>You're skinny.<end>",
#  '<start>He will be here soon.<end>',
#  '<start>How is your wife?<end>',
#  "<start>I'm from America.<end>",
#  "<start>Where've you been?<end>",
#  '<start>Tom was nowhere in sight.<end>',
#  '<start>Tom is dead.<end>',
#  '<start>I like their house.<end>',
#  "<start>I'm methodical.<end>",
#  '<start>Who are you all?<end>',
#  "<start>It's true!<end>",
#  "<start>Here's the address.<end>",
#  '<start>Stop worrying.<end>',
#  '<start>Everyone needs to stay focused.<end>',
#  "<start>The baby's name was Tom.<end>",
#  '<start>Tom is being very cooperative.<end>',
#  '<start>Control your fear.<end>',
#  '<start>I need some water.<end>',
#  '<start>Is anybody hurt?<end>',
#  '<start>He held his breath.<end>',
#  '<start>Do you have Time magazine?<end>',
#  '<start>He predicted she would win.<end>',
#  "<start>This isn't an easy task.<end>",
#  '<start>I know it was you.<end>',
#  '<start>She beat him to death.<end>',
#  '<start>Who are you there with?<end>',
#  "<start>I'll be careful.<end>",
#  '<start>What time are you coming?<end>',
#  "<start>I'll allow this.<end>",
#  '<start>Do you like Boston?<end>',
#  '<start>I have a business partner.<end>',
#  '<start>Who are you waiting for?<end>',
#  "<start>You're punctual.<end>",
#  '<start>I want to go there.<end>',
#  '<start>What results do you anticipate?<end>',
#  "<start>That's important.<end>",
#  '<start>She likes the teacher.<end>',
#  "<start>We're successful.<end>",
#  "<start>What's your name?<end>",
#  '<start>This is a real surprise.<end>',
#  '<start>Who do you know here?<end>',
#  '<start>I was planning on it.<end>',
#  '<start>Sit down and shut up.<end>',
#  "<start>I don't like your boss.<end>",
#  "<start>He'll be done soon.<end>",
#  '<start>Do you like dogs?<end>',
#  "<start>You're not very funny.<end>",
#  '<start>I love that song.<end>',
#  '<start>They invaded the country.<end>',
#  "<start>Let's have a drink first.<end>",
#  '<start>It was quite funny.<end>',
#  '<start>I just got promoted.<end>',
#  "<start>I'd like to stand.<end>",
#  "<start>That candle isn't white.<end>",
#  "<start>Let's do our best.<end>",
#  '<start>Find the differences.<end>',
#  '<start>Is this your wallet?<end>',
#  "<start>I'll come with you.<end>",
#  '<start>I want to stay alive.<end>',
#  "<start>I'm all thumbs.<end>",
#  '<start>We are here.<end>',
#  '<start>I have another idea.<end>',
#  "<start>It doesn't belong to you.<end>",
#  "<start>I'll leave that to you.<end>",
#  '<start>They went to bed late.<end>',
#  '<start>Save Tom.<end>',
#  '<start>Do I need to transfer?<end>',
#  '<start>It seems interesting to me.<end>',
#  "<start>You're too polite.<end>",
#  "<start>You're too naive.<end>",
#  "<start>I've got something to do.<end>",
#  "<start>You're always saying that.<end>",
#  '<start>I like this.<end>',
#  '<start>My wife hates cats.<end>',
#  '<start>Where exactly did you go?<end>',
#  "<start>They're expensive.<end>",
#  "<start>Don't tell anyone about this.<end>",
#  '<start>These animals are friendly.<end>',
#  '<start>Go and open the door.<end>',
#  '<start>Are you sleepy?<end>',
#  "<start>I'm counting on your help.<end>",
#  '<start>This is incredible.<end>',
#  '<start>Stop staring.<end>',
#  '<start>Thank you for your explanation.<end>',
#  '<start>That would be weird.<end>',
#  "<start>I'm studying in the library.<end>",
#  '<start>He who hesitates is lost.<end>',
#  '<start>Maybe next time.<end>',
#  '<start>Let me call my lawyer.<end>',
#  '<start>Will you join us?<end>',
#  '<start>You were never alone.<end>',
#  '<start>Who were you protecting?<end>',
#  '<start>I was a little disappointed.<end>',
#  "<start>I've got plans.<end>",
#  '<start>That should be enough.<end>',
#  '<start>She cried.<end>',
#  '<start>Come and see me.<end>',
#  '<start>The baby is crying.<end>',
#  "<start>Where's my money?<end>",
#  '<start>His new film is disappointing.<end>',
#  '<start>I like surprises.<end>',
#  '<start>Do you travel a lot?<end>',
#  "<start>He's after me.<end>",
#  '<start>I think about them often.<end>',
#  '<start>I recommend it highly.<end>',
#  '<start>Are you still thirsty?<end>',
#  '<start>He has a pleasant voice.<end>',
#  '<start>This plan has no flaws.<end>',
#  "<start>It isn't optional.<end>",
#  '<start>Tom pulled the rope.<end>',
#  '<start>I had a similar experience.<end>',
#  '<start>They look bored.<end>',
#  '<start>I was pardoned.<end>',
#  "<start>They're spies.<end>",
#  '<start>This is the perfect location.<end>',
#  '<start>I ought to go.<end>',
#  "<start>I'm coming to help you.<end>",
#  '<start>I run every morning.<end>',
#  '<start>Are you unlucky?<end>',
#  '<start>Duty calls.<end>',
#  '<start>The job is almost done.<end>',
#  "<start>I'm dedicated.<end>",
#  '<start>This blouse is cotton.<end>',
#  '<start>This is kind of expensive.<end>',
#  '<start>I was astonished.<end>',
#  "<start>I don't understand this.<end>",
#  "<start>Look at Tom's shoes.<end>",
#  '<start>Tom is on the roof.<end>',
#  "<start>This telephone doesn't work.<end>",
#  '<start>Where is my comb?<end>',
#  "<start>He's a strange character.<end>",
#  '<start>Tom trusts me.<end>',
#  '<start>At first, it is difficult.<end>',
#  '<start>Can you ride a horse?<end>',
#  '<start>I owe you an explanation.<end>',
#  '<start>The man is right.<end>',
#  '<start>Is this seat vacant?<end>',
#  "<start>That's more than I expected.<end>",
#  '<start>I remember that speech.<end>',
#  '<start>Are you in the house?<end>',
#  '<start>Who else was there?<end>',
#  '<start>I owe him $100.<end>',
#  '<start>We all have a price.<end>',
#  '<start>I study at the library.<end>',
#  '<start>That was the goal.<end>',
#  '<start>Was that a squirrel?<end>',
#  '<start>You must be careful.<end>',
#  '<start>Did you already do that?<end>',
#  '<start>I love my home.<end>',
#  "<start>He's wet.<end>",
#  '<start>We wanted you.<end>',
#  '<start>What a jerk!<end>',
#  '<start>We loved you.<end>',
#  '<start>I wish I were clever.<end>',
#  '<start>He got very drunk.<end>',
#  "<start>We're just tired.<end>",
#  '<start>He landed a big trout.<end>',
#  '<start>This operation is simple.<end>',
#  '<start>This idea is controversial.<end>',
#  '<start>That would be wonderful.<end>',
#  '<start>He plays very well.<end>',
#  '<start>Look closely.<end>',
#  '<start>Would you like one?<end>',
#  '<start>Tom is staying for dinner.<end>',
#  '<start>Be polite, but firm.<end>',
#  '<start>I really need you.<end>',
#  '<start>Why are you so arrogant?<end>',
#  '<start>You look like a boy.<end>',
#  "<start>You're incredibly talented.<end>",
#  '<start>Our allies are weak.<end>',
#  '<start>This job pays pretty well.<end>',
#  '<start>I like playing football.<end>',
#  '<start>They lied.<end>',
#  "<start>I never would've allowed that.<end>",
#  "<start>It's a social problem.<end>",
#  '<start>Nobody owns the moon.<end>',
#  "<start>I don't understand opera.<end>",
#  "<start>She's busy.<end>",
#  '<start>Everyone likes him.<end>',
#  '<start>He is eager to succeed.<end>',
#  '<start>Is that your bicycle?<end>',
#  '<start>There was nobody there.<end>',
#  "<start>Let's get married.<end>",
#  '<start>Everything is set.<end>',
#  "<start>You've been selected.<end>",
#  "<start>It's a bit flimsy.<end>",
#  '<start>You have to try again.<end>',
#  '<start>Have you received the letter?<end>',
#  '<start>Now drink up.<end>',
#  '<start>You look nervous.<end>',
#  '<start>I was 13 in 2003.<end>',
#  '<start>I believe in ghosts.<end>',
#  '<start>No one recognized you.<end>',
#  "<start>You're a wonderful friend.<end>",
#  '<start>How are you feeling today?<end>',
#  "<start>Let's get it over with.<end>",
#  '<start>Stand aside.<end>',
#  '<start>We hugged each other.<end>',
#  '<start>I will help.<end>',
#  '<start>How is the weather?<end>',
#  '<start>Lock the office.<end>',
#  '<start>I followed you.<end>',
#  "<start>Let's be reasonable.<end>",
#  "<start>Don't waste your ammunition.<end>",
#  "<start>That's what I asked for.<end>",
#  '<start>I slept like a baby.<end>',
#  '<start>I need you right now.<end>',
#  '<start>You are the one.<end>',
#  '<start>Tom refused to go.<end>',
#  '<start>You need to study harder.<end>',
#  '<start>She accepted his gift.<end>',
#  '<start>Do you like his songs?<end>',
#  '<start>Tom has lost his wallet.<end>',
#  "<start>We're friends, right?<end>",
#  "<start>I'm really happy.<end>",
#  "<start>I don't like big dogs.<end>",
#  '<start>Do you know my husband?<end>',
#  "<start>I'd like to cooperate.<end>",
#  "<start>I'm just tired.<end>",
#  '<start>Are you hurt?<end>',
#  '<start>Are you here on holiday?<end>',
#  '<start>How much did you bring?<end>',
#  '<start>Do your homework right away.<end>',
#  '<start>Which cup is yours?<end>',
#  '<start>Tom is always cheerful.<end>',
#  "<start>I don't like anything here.<end>",
#  "<start>We'll soon find out.<end>",
#  '<start>Buy it for me, please.<end>',
#  '<start>Try this instead.<end>',
#  '<start>Who is this girl?<end>',
#  '<start>Go and see the doctor.<end>',
#  "<start>Aren't you embarrassed?<end>",
#  '<start>You have my sympathies.<end>',
#  "<start>I'm a bit busy.<end>",
#  "<start>Everyone's asleep.<end>",
#  "<start>You're not allowed in there.<end>",
#  '<start>Tom is multilingual.<end>',
#  '<start>This is a joke.<end>',
#  "<start>It's very onerous.<end>",
#  '<start>Our apple tree is blooming.<end>',
#  '<start>Stop whimpering.<end>',
#  '<start>He stopped the car.<end>',
#  '<start>Put down your weapons!<end>',
#  '<start>Did you ask the price?<end>',
#  "<start>Where's Tom?<end>",
#  "<start>Your life's in danger.<end>",
#  "<start>I promise I'll call.<end>",
#  '<start>I got paid today.<end>',
#  "<start>I've done that countless times.<end>",
#  '<start>She is a good writer.<end>',
#  '<start>Tell Tom the truth.<end>',
#  '<start>They are bored.<end>',
#  '<start>I am only joking.<end>',
#  '<start>Anyone could do that.<end>',
#  '<start>He is poor, but happy.<end>',
#  '<start>Face facts!<end>',
#  '<start>The apartment is in flames.<end>',
#  "<start>We didn't order this.<end>",
#  "<start>You don't owe me anything.<end>",
#  '<start>I bought a house.<end>',
#  '<start>These gifts are for you.<end>',
#  '<start>Tom is still confident.<end>',
#  '<start>I will shoot him.<end>',
#  "<start>Tom's innocent.<end>",
#  "<start>I've lost confidence in Tom.<end>",
#  '<start>You owe me an apology.<end>',
#  '<start>I needed it yesterday.<end>',
#  "<start>He doesn't know yet.<end>",
#  '<start>That was a close call.<end>',
#  '<start>I like movies.<end>',
#  '<start>I learned that from you.<end>',
#  '<start>Can I come over?<end>',
#  "<start>Don't light the candle.<end>",
#  '<start>She seems to be unhappy.<end>',
#  "<start>We're experienced.<end>",
#  '<start>Tom is making a video.<end>',
#  '<start>Those photos are hers.<end>',
#  "<start>I'll get it.<end>",
#  "<start>I don't smoke.<end>",
#  '<start>The plates are dirty.<end>',
#  '<start>Tom is a monster.<end>',
#  '<start>The clock is ticking.<end>',
#  "<start>You're extroverted.<end>",
#  '<start>You got here too early.<end>',
#  '<start>I will miss you.<end>',
#  '<start>Hand in your papers.<end>',
#  '<start>He promised to marry her.<end>',
#  "<start>I don't like your name.<end>",
#  '<start>You have to be strong.<end>',
#  "<start>I'm writing a song.<end>",
#  '<start>The wind is shifting.<end>',
#  "<start>They're mad at you.<end>",
#  '<start>These shoes belong to Tom.<end>',
#  '<start>We took a cab.<end>',
#  '<start>Yesterday I helped my father.<end>',
#  "<start>That's not my call.<end>",
#  '<start>They were just gambling.<end>',
#  "<start>It's refreshing.<end>",
#  '<start>Could you cancel my reservation?<end>',
#  '<start>About what time?<end>',
#  '<start>You freaked me out.<end>',
#  '<start>We missed the plane.<end>',
#  "<start>It'll be tricky.<end>",
#  '<start>Tom still loves his job.<end>',
#  '<start>He is a handsome man.<end>',
#  '<start>Are these yours?<end>',
#  '<start>Are you kidding?<end>',
#  '<start>We came together.<end>',
#  '<start>Take it all.<end>',
#  '<start>I hate being photographed.<end>',
#  '<start>Are they still in bed?<end>',
#  '<start>Thanks for having me.<end>',
#  '<start>Please leave.<end>',
#  '<start>Do you recycle?<end>',
#  '<start>They were talking about you.<end>',
#  '<start>The squirrel climbed the tree.<end>',
#  '<start>I heard someone scream.<end>',
#  '<start>I have a dictionary.<end>',
#  '<start>Why are you alone?<end>',
#  '<start>It is kind of pretty.<end>',
#  '<start>Remove your hat.<end>',
#  '<start>I have serious doubts.<end>',
#  '<start>Judge for yourself.<end>',
#  '<start>I was pleased.<end>',
#  '<start>He is a good singer.<end>',
#  '<start>I suggest you leave.<end>',
#  '<start>He is breathing hard.<end>',
#  '<start>The bath is ready.<end>',
#  '<start>I suggest you listen carefully.<end>',
#  '<start>The toilet is over there.<end>',
#  '<start>The car bumped the tree.<end>',
#  '<start>Spiders scare me.<end>',
#  '<start>I wish you luck.<end>',
#  '<start>Thank you for your recommendation.<end>',
#  "<start>I'm innocent.<end>",
#  '<start>Can you hear us?<end>',
#  "<start>What's this really about?<end>",
#  '<start>I have a sharp knife.<end>',
#  '<start>Who knows?<end>',
#  '<start>This knife cuts well.<end>',
#  "<start>You're replaceable.<end>",
#  '<start>Get a hold of yourself.<end>',
#  '<start>Some of the girls laughed.<end>',
#  '<start>Hurry up, girls.<end>',
#  '<start>It really was hard.<end>',
#  '<start>Spare me the grisly details.<end>',
#  '<start>Do you want some coffee?<end>',
#  '<start>You control your destiny.<end>',
#  "<start>Don't ask me that again.<end>",
#  '<start>Does he like me?<end>',
#  "<start>It's not so good.<end>",
#  '<start>You look sad today.<end>',
#  "<start>You're very clever.<end>",
#  '<start>Who am I forgetting?<end>',
#  '<start>Who can prevent it?<end>',
#  '<start>Be merciful.<end>',
#  '<start>Those houses are big.<end>',
#  "<start>Let's do it again.<end>",
#  "<start>That's your favorite, right?<end>",
#  "<start>There's no rush.<end>",
#  '<start>Read this now.<end>',
#  '<start>He took his time.<end>',
#  '<start>See you in three months.<end>',
#  "<start>The joke's on you.<end>",
#  "<start>I've waited for a month.<end>",
#  "<start>We're imagining things.<end>",
#  '<start>My scalp is very itchy.<end>',
#  "<start>I'm not done.<end>",
#  '<start>We want more food.<end>',
#  '<start>What an idea!<end>',
#  '<start>Love is not enough.<end>',
#  '<start>My grandfather has a dog.<end>',
#  "<start>Don't get too excited.<end>",
#  '<start>It seems very interesting.<end>',
#  '<start>Do you have any beer?<end>',
#  '<start>I share your opinion.<end>',
#  "<start>I'm being honest with you.<end>",
#  "<start>I'm seeing her this evening.<end>",
#  '<start>Our train is late.<end>',
#  "<start>Don't underestimate my power.<end>",
#  '<start>Tom split up with Mary.<end>',
#  '<start>We survived.<end>',
#  '<start>He twisted my arm.<end>',
#  '<start>I will miss you all.<end>',
#  "<start>She's just a child.<end>",
#  "<start>Don't think about that anymore.<end>",
#  "<start>You're too skinny.<end>",
#  '<start>Sit right there.<end>',
#  '<start>I write poems.<end>',
#  '<start>Do you mind much?<end>',
#  '<start>You broke your arm.<end>',
#  '<start>No problem at all!<end>',
#  "<start>This clock isn't working.<end>",
#  '<start>Tom made no comment.<end>',
#  '<start>Would you play with me?<end>',
#  '<start>I had something planned.<end>',
#  "<start>I can't wait to leave.<end>",
#  '<start>He believes he knows everything.<end>',
#  '<start>I almost drowned.<end>',
#  '<start>You need to work together.<end>',
#  "<start>I'm hit!<end>",
#  '<start>I work at this company.<end>',
#  "<start>We're your last hope.<end>",
#  "<start>The sky's clear today.<end>",
#  '<start>We could write a book.<end>',
#  "<start>It's incredible, isn't it?<end>",
#  '<start>Planes are expensive.<end>',
#  '<start>Is this seat empty?<end>',
#  '<start>Did you volunteer us?<end>',
#  '<start>What evidence do you have?<end>',
#  "<start>That's a fact.<end>",
#  '<start>This time will be different.<end>',
#  "<start>You're very understanding.<end>",
#  '<start>Leave me alone.<end>',
#  '<start>Both alternatives are possible.<end>',
#  '<start>Does anybody hear me?<end>',
#  '<start>I like westerns.<end>',
#  "<start>You're very brave.<end>",
#  "<start>They're going to try.<end>",
#  '<start>She has been to Paris.<end>',
#  '<start>I swim in the summer.<end>',
#  '<start>They all looked happy.<end>',
#  '<start>It has cooled off.<end>',
#  '<start>We want to win.<end>',
#  '<start>You seem depressed.<end>',
#  '<start>I made a list.<end>',
#  '<start>You need to stop.<end>',
#  "<start>Who's at the wheel?<end>",
#  "<start>Everyone's lying.<end>",
#  '<start>Their teacher praised them.<end>',
#  "<start>I'll go see.<end>",
#  "<start>They're talking.<end>",
#  '<start>What did the doctor say?<end>',
#  "<start>The rest doesn't matter.<end>",
#  '<start>He still loves her.<end>',
#  '<start>Tomorrow is my birthday.<end>',
#  '<start>Come with me now.<end>',
#  '<start>No news is good news.<end>',
#  '<start>I go to work.<end>',
#  '<start>They were victorious.<end>',
#  '<start>I like rock.<end>',
#  '<start>Where will you go?<end>',
#  '<start>This sandwich is good.<end>',
#  '<start>Have a good weekend.<end>',
#  '<start>She majored in history.<end>',
#  '<start>He kept the window closed.<end>',
#  '<start>Place it wherever you like.<end>',
#  "<start>Let's do something.<end>",
#  '<start>Tom lost hope.<end>',
#  '<start>Thank you for your help.<end>',
#  '<start>She altered her plans.<end>',
#  '<start>There is no timetable.<end>',
#  '<start>Birds build nests.<end>',
#  "<start>Don't come any closer.<end>",
#  "<start>It's very close.<end>",
#  '<start>This steak is very juicy.<end>',
#  '<start>Go kiss someone else.<end>',
#  '<start>How many were wounded?<end>',
#  '<start>Meet me at 2:30.<end>',
#  '<start>Is it really necessary?<end>',
#  '<start>I was petrified.<end>',
#  '<start>We tried our best.<end>',
#  '<start>What is critical thinking?<end>',
#  "<start>Don't drop that cup.<end>",
#  '<start>The day was exhausting.<end>',
#  '<start>Can that be achieved?<end>',
#  "<start>It's impossible to describe.<end>",
#  "<start>We'll have breakfast at 6:30.<end>",
#  '<start>He gave me an apple.<end>',
#  '<start>This is gibberish.<end>',
#  '<start>Wait a minute.<end>',
#  '<start>Get that book for me.<end>',
#  "<start>You've got to be bold!<end>",
#  '<start>Loosen up.<end>',
#  '<start>Is your headache gone?<end>',
#  '<start>He decided to marry her.<end>',
#  '<start>Open up the package.<end>',
#  '<start>Read this first.<end>',
#  '<start>Have you measured it?<end>',
#  '<start>She is very pretty.<end>',
#  '<start>I totally understand.<end>',
#  "<start>He's open and trusting.<end>",
#  '<start>She recognized him immediately.<end>',
#  '<start>The audience began to laugh.<end>',
#  '<start>He has no money.<end>',
#  '<start>Be as quick as possible.<end>',
#  '<start>The situation has stabilized.<end>',
#  '<start>Have you been here since?<end>',
#  '<start>Are you envious?<end>',
#  "<start>We're relaxed.<end>",
#  '<start>It was really dark.<end>',
#  '<start>Is Tom safe?<end>',
#  '<start>Just do your best.<end>',
#  '<start>Why would I laugh?<end>',
#  "<start>I'm a little bit busy.<end>",
#  '<start>Do your job.<end>',
#  '<start>You must respect your elders.<end>',
#  '<start>Have a safe journey.<end>',
#  "<start>What've you done?<end>",
#  '<start>Chew your food well.<end>',
#  '<start>Tom loves sports events.<end>',
#  '<start>I stopped laughing.<end>',
#  '<start>Tom is a client.<end>',
#  '<start>That is very expensive!<end>',
#  "<start>Let's start by introducing ourselves.<end>",
#  '<start>I caught a cold.<end>',
#  '<start>Do you know her?<end>',
#  "<start>You're too skinny.<end>",
#  '<start>No one saw that.<end>',
#  '<start>Tom went pale.<end>',
#  '<start>Be polite, but firm.<end>',
#  '<start>I felt scared.<end>',
#  '<start>Are you certain about this?<end>',
#  '<start>She is a famous singer.<end>',
#  "<start>Don't turn off your computer.<end>",
#  '<start>Did I surprise you?<end>',
#  "<start>They've had a talk.<end>",
#  '<start>The market is completely saturated.<end>',
#  '<start>Be discreet.<end>',
#  '<start>That would be really great.<end>',
#  '<start>Let me see it.<end>',
#  "<start>I'll watch television.<end>",
#  '<start>He sold us out.<end>',
#  '<start>I need a drink.<end>',
#  '<start>No one can help you.<end>',
#  "<start>What're you talking about?<end>",
#  "<start>I'm used to it.<end>",
#  "<start>Don't obey that man.<end>",
#  "<start>They're all the same.<end>",
#  '<start>The rumor quickly spread.<end>',
#  '<start>What would cause that?<end>',
#  '<start>I got something for you.<end>',
#  '<start>He likes sleeping.<end>',
#  "<start>I'll give it back.<end>",
#  '<start>Dinner is almost ready.<end>',
#  '<start>They found us.<end>',
#  '<start>Nothing makes Tom happy.<end>',
#  '<start>Tell me where Tom is.<end>',
#  '<start>Let us out.<end>',
#  "<start>Beautiful day, isn't it?<end>",
#  '<start>See you soon!<end>',
#  '<start>We made sure of it.<end>',
#  '<start>Am I fat?<end>',
#  '<start>I love parties.<end>',
#  '<start>I want him to leave.<end>',
#  '<start>Are we ready?<end>',
#  "<start>We're uninsured.<end>",
#  '<start>Open the windows.<end>',
#  '<start>Tom likes to play soccer.<end>',
#  '<start>That house belongs to me.<end>',
#  '<start>The request was granted.<end>',
#  "<start>You're courteous.<end>",
#  '<start>Disconnect the plug.<end>',
#  '<start>She liked it.<end>',
#  '<start>I was working late.<end>',
#  '<start>The plane increased speed.<end>',
#  '<start>Change is important.<end>',
#  '<start>This is urgent.<end>',
#  '<start>Did you hear that?<end>',
#  '<start>Tom has never met Mary.<end>',
#  '<start>That place is always packed.<end>',
#  "<start>It's really not important.<end>",
#  '<start>The news made her sad.<end>',
#  "<start>It's fun to travel.<end>",
#  '<start>I like this store.<end>',
#  '<start>None of them look surprised.<end>',
#  '<start>I feel safe.<end>',
#  '<start>I am a housewife.<end>',
#  '<start>I have a hangover.<end>',
#  '<start>Speak a little louder.<end>',
#  '<start>Stop being stupid.<end>',
#  "<start>Here's one of my favorites.<end>",
#  '<start>He whispered something to me.<end>',
#  "<start>That's a mistake.<end>",
#  "<start>It's incredibly powerful.<end>",
#  '<start>I used to play here.<end>',
#  '<start>Do you like music?<end>',
#  '<start>Monday was a windy day.<end>',
#  '<start>Tom has become a father.<end>',
#  '<start>Your prophecy has come true.<end>',
#  '<start>Tell me more.<end>',
#  '<start>Nobody showed up today.<end>',
#  '<start>Is that so terrible?<end>',
#  '<start>I lost your number.<end>',
#  '<start>Tom works all night.<end>',
#  '<start>Let me check my wallet.<end>',
#  '<start>This room is quiet.<end>',
#  '<start>You owe me a kiss.<end>',
#  "<start>That's really surprising.<end>",
#  '<start>I need a clean shirt.<end>',
#  '<start>Are you tired?<end>',
#  '<start>Why all the drama?<end>',
#  '<start>She has attractive eyes.<end>',
#  '<start>I learned a new trick.<end>',
#  '<start>It works.<end>',
#  '<start>Tell me where you went.<end>',
#  '<start>I have a telescope.<end>',
#  '<start>You crossed the line.<end>',
#  '<start>Let me grab my bag.<end>',
#  '<start>That was really bad.<end>',
#  '<start>Give me ten minutes.<end>',
#  '<start>Why is Tom here?<end>',
#  '<start>Please be polite.<end>',
#  '<start>Do you have a comb?<end>',
#  "<start>I admire Tom's dedication.<end>",
#  '<start>The situation is deteriorating.<end>',
#  '<start>Tom and Mary were young.<end>',
#  "<start>You won't be interested.<end>",
#  '<start>I am engaged to her.<end>',
#  '<start>Luck is against me.<end>',
#  '<start>Get back here.<end>',
#  "<start>I'm not well.<end>",
#  '<start>Tom teaches us French.<end>',
#  '<start>He flew to Paris.<end>',
#  "<start>I'm not very confident.<end>",
#  "<start>I've failed.<end>",
#  '<start>I hope they liked me.<end>',
#  "<start>Tom didn't do anything else.<end>",
#  '<start>I saw the file.<end>',
#  '<start>Hey, open the door.<end>',
#  '<start>Could you check the tires?<end>',
#  '<start>Please hurry up!<end>',
#  '<start>My trousers are wet.<end>',
#  "<start>I'm happy with it.<end>",
#  '<start>Can I touch it?<end>',
#  '<start>He lit the candles.<end>',
#  '<start>Tell us all the gossip.<end>',
#  '<start>Nobody was listening to us.<end>',
#  '<start>This is unsafe.<end>',
#  '<start>This is your country.<end>',
#  '<start>Why are you helping me?<end>',
#  "<start>You're all the same.<end>",
#  '<start>The possibilities are infinite.<end>',
#  '<start>That was ours.<end>',
#  '<start>I loved that.<end>',
#  '<start>Wait till six.<end>',
#  "<start>I'm not mean.<end>",
#  '<start>Tom pushed that thought aside.<end>',
#  '<start>Let him go.<end>',
#  '<start>What have we got?<end>',
#  "<start>I'm not being unreasonable.<end>",
#  "<start>That's not really necessary anymore.<end>",
#  '<start>I like my friends.<end>',
#  '<start>Everything was difficult.<end>',
#  '<start>When did you find out?<end>',
#  '<start>Get down from there.<end>',
#  '<start>I live in comfort.<end>',
#  '<start>Get out of my seat.<end>',
#  '<start>The water turned to ice.<end>',
#  "<start>I'm your sister.<end>",
#  '<start>Did you buy tomatoes?<end>',
#  '<start>The store was relatively empty.<end>',
#  "<start>That's totally justified.<end>",
#  "<start>I'm ruined.<end>",
#  "<start>It wasn't my idea.<end>",
#  '<start>The weather is nice tonight.<end>',
#  '<start>I feel very guilty.<end>',
#  "<start>I'll need your help.<end>",
#  '<start>You still have a chance.<end>',
#  '<start>We all have fun.<end>',
#  "<start>I'm chubby.<end>",
#  '<start>Did she say that?<end>',
#  "<start>Don't throw that away.<end>",
#  '<start>Work slowly.<end>',
#  "<start>We'll eat on the way.<end>",
#  '<start>You have beautiful hair.<end>',
#  '<start>It was astonishing.<end>',
#  '<start>My internet connection is slow.<end>',
#  '<start>I like your earrings.<end>',
#  "<start>He's a smooth talker.<end>",
#  '<start>He is a heroin addict.<end>',
#  '<start>Your French is good.<end>',
#  '<start>Did I hurt you?<end>',
#  '<start>We were really cold.<end>',
#  "<start>I'm in charge of that.<end>",
#  '<start>Everybody loves her.<end>',
#  '<start>They want to kill me.<end>',
#  "<start>Here's your drink.<end>",
#  "<start>It'll be very hot tomorrow.<end>",
#  '<start>Who gave it to you?<end>',
#  '<start>Stay sharp.<end>',
#  '<start>Here are the tickets.<end>',
#  '<start>She moved my clothes.<end>',
#  '<start>This is an important letter.<end>',
#  '<start>They died one after another.<end>',
#  '<start>Are they cops?<end>',
#  "<start>What's your explanation?<end>",
#  '<start>We sat in the front.<end>',
#  "<start>You're not that interesting.<end>",
#  '<start>Tom likes to play tennis.<end>',
#  "<start>That's very kind of you.<end>",
#  '<start>Tom likes country.<end>',
#  "<start>You're all against me.<end>",
#  "<start>I didn't ask for help.<end>",
#  "<start>That's a blue house.<end>",
#  '<start>I have one brother.<end>',
#  "<start>Vacation's already over.<end>",
#  "<start>I didn't vote.<end>",
#  '<start>I have no objection.<end>',
#  '<start>She sleeps with two pillows.<end>',
#  '<start>Call the cops.<end>',
#  "<start>I'll meet you outside.<end>",
#  "<start>I didn't see anything.<end>",
#  "<start>I'm making progress.<end>",
#  '<start>Are you insured?<end>',
#  '<start>I loved the play.<end>',
#  '<start>May I borrow this book?<end>',
#  '<start>He is good for nothing.<end>',
#  '<start>I like stories.<end>',
#  '<start>Please come.<end>',
#  "<start>Let's play baseball.<end>",
#  '<start>We have a deadline.<end>',
#  "<start>Don't forget to vote.<end>",
#  '<start>He died in his bed.<end>',
#  '<start>I want a doctor.<end>',
#  '<start>Please lower the window.<end>',
#  '<start>Bring me the newspaper.<end>',
#  '<start>Are you sure?<end>',
#  "<start>I'll wait in the gym.<end>",
#  '<start>They paid separately.<end>',
#  '<start>Do you realize that?<end>',
#  "<start>I didn't vote for anyone.<end>",
#  "<start>She's my friend.<end>",
#  '<start>Do you like baseball?<end>',
#  '<start>He called at my house.<end>',
#  '<start>Tom is OK now.<end>',
#  "<start>You're flattering me.<end>",
#  "<start>We're kind of busy here.<end>",
#  '<start>He crossed the river.<end>',
#  "<start>He's a meth addict.<end>",
#  '<start>This hat is yours.<end>',
#  '<start>The commander refused to negotiate.<end>',
#  '<start>Congratulations on your anniversary.<end>',
#  '<start>We like Tom.<end>',
#  '<start>She aimed at the target.<end>',
#  '<start>The office is empty.<end>',
#  '<start>Do you enjoy living dangerously?<end>',
#  '<start>He slept an hour.<end>',
#  '<start>They were both drunk.<end>',
#  '<start>That sounds outrageous.<end>',
#  '<start>He told the truth.<end>',
#  '<start>He changed his mind.<end>',
#  '<start>This umbrella looks like mine.<end>',
#  "<start>I'm drinking water.<end>",
#  '<start>Put it there, not here.<end>',
#  '<start>Where are my children?<end>',
#  "<start>I've always loved you.<end>",
#  '<start>Is it difficult work?<end>',
#  '<start>Have you ever been lonely?<end>',
#  "<start>That's certainly possible.<end>",
#  '<start>Tom was obviously offended.<end>',
#  '<start>Dublin is in Ireland.<end>',
#  "<start>You're very tall.<end>",
#  '<start>I was so disappointed.<end>',
#  "<start>You like Boston, don't you?<end>",
#  '<start>Woods burn easily.<end>',
#  '<start>Pick a card.<end>',
#  '<start>A piano is expensive.<end>',
#  '<start>He lives by himself.<end>',
#  '<start>Everything worked fine.<end>',
#  "<start>The game's almost over.<end>",
#  '<start>This is all for you.<end>',
#  '<start>Might makes right.<end>',
#  '<start>I think they like you.<end>',
#  '<start>Look at us.<end>',
#  '<start>They discussed the problem.<end>',
#  "<start>You're quite safe.<end>",
#  '<start>You should be careful.<end>',
#  "<start>I'm managing.<end>",
#  "<start>You're still alive.<end>",
#  '<start>You almost died.<end>',
#  '<start>I do sympathize with you.<end>',
#  '<start>It was all over.<end>',
#  '<start>He was brought to tears.<end>',
#  '<start>You seem different.<end>',
#  '<start>Coffee, please.<end>',
#  '<start>He called me a cab.<end>',
#  '<start>This is what he painted.<end>',
#  '<start>Get out of the water.<end>',
#  '<start>A scream broke the silence.<end>',
#  "<start>I'm chicken.<end>",
#  '<start>I am a college student.<end>',
#  '<start>Are you Japanese?<end>',
#  '<start>What are your measurements?<end>',
#  '<start>Where were you born?<end>',
#  '<start>He can read and write.<end>',
#  '<start>Where are they sending us?<end>',
#  '<start>All men are created equal.<end>',
#  '<start>No stitches were needed.<end>',
#  '<start>Are you injured?<end>',
#  '<start>I have no experience.<end>',
#  '<start>They voted.<end>',
#  "<start>I'm really shocked.<end>",
#  "<start>I didn't like that.<end>",
#  '<start>Tom is a lumberjack.<end>',
#  '<start>Cheers!<end>',
#  "<start>It's for you.<end>",
#  '<start>Where are they swimming?<end>',
#  '<start>They said no.<end>',
#  "<start>I've been misunderstood.<end>",
#  '<start>Three weeks went by.<end>',
#  "<start>She's not a liar.<end>",
#  "<start>I haven't forgotten.<end>",
#  '<start>The weather is nice today.<end>',
#  "<start>They're not coming.<end>",
#  "<start>Don't be mean.<end>",
#  "<start>Tom doesn't like singing.<end>",
#  "<start>It's raining here.<end>",
#  '<start>Is it hot?<end>',
#  "<start>They're all fake.<end>",
#  '<start>I had no idea.<end>',
#  '<start>Police arrested one man.<end>',
#  '<start>I prefer to stay here.<end>',
#  '<start>The moon is out.<end>',
#  "<start>She's very tall.<end>",
#  '<start>Nice timing.<end>',
#  "<start>I've never lied to you.<end>",
#  '<start>I like elephants.<end>',
#  '<start>I insist on that.<end>',
#  '<start>Does truth matter?<end>',
#  '<start>She does look tired.<end>',
#  "<start>He hasn't changed his mind.<end>",
#  '<start>Take a number.<end>',
#  '<start>Tom is dating someone.<end>',
#  '<start>I always obey the rules.<end>',
#  "<start>I've lost all my money.<end>",
#  '<start>You can do it.<end>',
#  '<start>Did you shoot Tom?<end>',
#  '<start>Tom broke up with me.<end>',
#  "<start>You're great at this.<end>",
#  '<start>She sang pretty well.<end>',
#  '<start>Do you want any?<end>',
#  '<start>God made the universe.<end>',
#  "<start>What's in front of you?<end>",
#  '<start>He drives a hard bargain.<end>',
#  "<start>You're not fat.<end>",
#  '<start>Have a safe trip.<end>',
#  "<start>We'll see you again.<end>",
#  '<start>Say that again.<end>',
#  '<start>It is an option.<end>',
#  '<start>I have plans.<end>',
#  '<start>What a night!<end>',
#  '<start>Do you think it works?<end>',
#  '<start>We must take that chance.<end>',
#  '<start>Did I miss the turn?<end>',
#  "<start>I don't hear barking.<end>",
#  "<start>I admit that I'm tired.<end>",
#  '<start>She promised to marry him.<end>',
#  '<start>You seem distracted today.<end>',
#  '<start>I burned it.<end>',
#  '<start>Why did they hire you?<end>',
#  '<start>Have you finished your meal?<end>',
#  '<start>Mine is totally different.<end>',
#  '<start>I feel so helpless.<end>',
#  '<start>Tom lit the candles.<end>',
#  '<start>We called off the wedding.<end>',
#  "<start>You're very funny.<end>",
#  "<start>We're going back to Boston.<end>",
#  '<start>He has no more strength.<end>',
#  '<start>I could walk.<end>',
#  '<start>I believe in miracles.<end>',
#  '<start>I know.<end>',
#  '<start>He will also go.<end>',
#  '<start>Are you watching carefully?<end>',
#  '<start>It was very funny.<end>',
#  '<start>War is evil.<end>',
#  '<start>Are you in a hurry?<end>',
#  '<start>What are you playing with?<end>',
#  '<start>The shoes are worn out.<end>',
#  "<start>That's my money.<end>",
#  "<start>I'll go change my clothes.<end>",
#  '<start>I got over that.<end>',
#  '<start>Everything looked nice.<end>',
#  '<start>I think I was wrong.<end>',
#  '<start>I met them.<end>',
#  '<start>He works long hours.<end>',
#  '<start>She still loves him.<end>',
#  '<start>Do you want to go?<end>',
#  "<start>I think that's undeniable.<end>",
#  '<start>He owes me one.<end>',
#  '<start>One minute has sixty seconds.<end>',
#  '<start>It looks really good.<end>',
#  '<start>He touched my shoulder.<end>',
#  '<start>Are you lonely?<end>',
#  '<start>Your eggs are getting cold.<end>',
#  '<start>Tom is a lazy person.<end>',
#  '<start>Are you both crazy?<end>',
#  '<start>When did this occur?<end>',
#  '<start>This is my fate.<end>',
#  '<start>I need an escort.<end>',
#  '<start>What are you reading?<end>',
#  '<start>Is there someone with you?<end>',
#  '<start>He is afraid of death.<end>',
#  '<start>He raised his arm.<end>',
#  '<start>That was sweet.<end>',
#  "<start>You're not late.<end>",
#  '<start>You can count on him.<end>',
#  '<start>He hates himself.<end>',
#  '<start>I felt very happy.<end>',
#  '<start>I drive everywhere.<end>',
#  "<start>I'm lonely.<end>",
#  "<start>It's a beautiful picture.<end>",
#  '<start>You will miss the train.<end>',
#  '<start>There are only three left.<end>',
#  '<start>You always say that.<end>',
#  "<start>I've just finished lunch.<end>",
#  '<start>Are you leaving today?<end>',
#  "<start>I'll take care of those.<end>",
#  '<start>Stay in the house.<end>',
#  '<start>Who helps her?<end>',
#  '<start>I have to go back.<end>',
#  '<start>What medications are you taking?<end>',
#  "<start>I'm your partner.<end>",
#  '<start>She baked me a cake.<end>',
#  '<start>He is precious to us.<end>',
#  '<start>He left me the keys.<end>',
#  '<start>The butcher ground the meat.<end>',
#  '<start>Bring your children with you.<end>',
#  "<start>There's a book here.<end>",
#  '<start>Do you have a cellphone?<end>',
#  '<start>It just came out.<end>',
#  '<start>Did you like this book?<end>',
#  '<start>I checked everywhere.<end>',
#  '<start>I was just looking around.<end>',
#  "<start>You're blocking my view.<end>",
#  '<start>I heard yelling.<end>',
#  '<start>I hate my roommate.<end>',
#  "<start>What's the weather like today?<end>",
#  '<start>I have a green shirt.<end>',
#  "<start>We'll all be there.<end>",
#  '<start>Do you want to dance?<end>',
#  '<start>Can I have one?<end>',
#  '<start>I feel ashamed.<end>',
#  '<start>Are you healthy?<end>',
#  "<start>You're very attractive.<end>",
#  '<start>What a bad movie!<end>',
#  '<start>Tom is kidding.<end>',
#  '<start>Get on your feet.<end>',
#  "<start>It's time to eat lunch.<end>",
#  "<start>You're fascinating.<end>",
#  "<start>I really don't understand anything.<end>",
#  "<start>I'll sleep on the floor.<end>",
#  '<start>The circumstances were different then.<end>',
#  "<start>They won't be here long.<end>",
#  '<start>You are the one.<end>',
#  "<start>It's hard to tell.<end>",
#  "<start>I don't remember anymore.<end>",
#  "<start>You're the best.<end>",
#  '<start>I made a bad decision.<end>',
#  "<start>The door's locked.<end>",
#  '<start>She is hard at work.<end>',
#  '<start>We saw nothing.<end>',
#  '<start>Your mother is very young.<end>',
#  '<start>I really liked that movie.<end>',
#  '<start>Maybe we can fix this.<end>',
#  "<start>He's a bit jealous.<end>",
#  '<start>My mother was in tears.<end>',
#  '<start>What did it feel like?<end>',
#  '<start>I love Christmas.<end>',
#  '<start>Tom was unfriendly to Mary.<end>',
#  '<start>Catch me if you can.<end>',
#  '<start>You should go to school.<end>',
#  '<start>You are hopeless.<end>',
#  "<start>That's great!<end>",
#  '<start>He goes to school.<end>',
#  '<start>Have you got it yet?<end>',
#  "<start>You're not invincible.<end>",
#  "<start>You're a failure.<end>",
#  '<start>Proceed with caution.<end>',
#  '<start>I needed to meet you.<end>',
#  "<start>I can't protect you.<end>",
#  "<start>I'll guide you.<end>",
#  '<start>It might not be enough.<end>',
#  '<start>Do you write in French?<end>',
#  "<start>I don't have kids.<end>",
#  '<start>Father manages the store.<end>',
#  "<start>I've ordered you a beer.<end>",
#  '<start>They were tired of waiting.<end>',
#  '<start>They look cool.<end>',
#  "<start>Let's hit the road.<end>",
#  '<start>I smelled it.<end>',
#  "<start>It's pretty bad.<end>",
#  '<start>The best hairdressers are gay.<end>',
#  '<start>She looked after the child.<end>',
#  '<start>Where are we going tonight?<end>',
#  "<start>You're going to be OK.<end>",
#  '<start>He regretted having been lazy.<end>',
#  '<start>I burned the cake.<end>',
#  "<start>Why don't you come in?<end>",
#  '<start>Forget it.<end>',
#  '<start>Were you born there?<end>',
#  "<start>I'm learning English.<end>",
#  '<start>Tom seems jealous.<end>',
#  '<start>Are rabbits able to swim?<end>',
#  '<start>This dog bites.<end>',
#  '<start>She turned on the TV.<end>',
#  ...]

# %%
french_train = get_data(list(train['French words/sentences']))

# %%
french_train
# Out:
# ['<start>Il pleuvait.<end>',
#  '<start>Tom apprécie certainement son vin.<end>',
#  '<start>Il interpréta pour moi.<end>',
#  "<start>J'ai dégueulassé.<end>",
#  '<start>Vous êtes maigrichonnes.<end>',
#  '<start>Il sera bientôt là.<end>',
#  '<start>Comment va ta femme\u202f?<end>',
#  "<start>Je viens d'Amérique.<end>",
#  '<start>Où as-tu été ?<end>',
#  '<start>Tom était introuvable.<end>',
#  '<start>Tom est mort.<end>',
#  "<start>J'aime leur maison.<end>",
#  '<start>Je suis méthodique.<end>',
#  '<start>Qui êtes-vous tous\u202f?<end>',
#  "<start>C'est vrai\u202f!<end>",
#  "<start>Voici l'adresse.<end>",
#  "<start>Arrête de t'inquiéter.<end>",
#  '<start>Chacun doit rester concentré.<end>',
#  "<start>Le bébé s'appelait Tom.<end>",
#  '<start>Tom se montre très coopératif.<end>',
#  '<start>Contrôle ta peur.<end>',
#  "<start>J'ai besoin d'eau.<end>",
#  '<start>Quiconque est-il blessé ?<end>',
#  '<start>Il a retenu son souffle.<end>',
#  '<start>As-tu le magazine Time\xa0?<end>',
#  "<start>Il a prédit qu'elle gagnerait.<end>",
#  "<start>Ce n'est pas tâche facile.<end>",
#  "<start>Je sais que c'était toi.<end>",
#  "<start>Elle l'a battu à mort.<end>",
#  '<start>Avec qui y es-tu ?<end>',
#  '<start>Je serai prudente.<end>',
#  '<start>À quelle heure venez-vous ?<end>',
#  '<start>Je le permettrai.<end>',
#  '<start>Aimes-tu Boston\xa0?<end>',
#  "<start>J'ai un partenaire en affaires.<end>",
#  '<start>Qui sers-tu\u202f?<end>',
#  '<start>Tu es ponctuel.<end>',
#  '<start>Je veux y aller.<end>',
#  '<start>Quels résultats attends-tu ?<end>',
#  "<start>C'est important.<end>",
#  '<start>Elle aime la maitresse.<end>',
#  '<start>Nous connaissons la réussite.<end>',
#  "<start>Comment tu t'appelles ?<end>",
#  "<start>C'est une vraie surprise.<end>",
#  '<start>Qui connais-tu ici ?<end>',
#  "<start>Je m'y attendais.<end>",
#  '<start>Assois-toi et tais-toi !<end>',
#  "<start>Je n'aime pas ta patronne.<end>",
#  '<start>Il va bientôt finir.<end>',
#  '<start>Aimes-tu les chiens ?<end>',
#  "<start>Vous n'êtes pas très amusante.<end>",
#  "<start>J'adore cette chanson.<end>",
#  '<start>Ils ont envahi le pays.<end>',
#  "<start>Buvons un verre d'abord.<end>",
#  '<start>Ça a été assez amusant.<end>',
#  "<start>Je viens d'être promue.<end>",
#  "<start>J'aimerais me lever.<end>",
#  "<start>Cette bougie n'est pas blanche.<end>",
#  '<start>Faisons de notre mieux.<end>',
#  '<start>Trouve les différences !<end>',
#  '<start>Est-ce votre portefeuille\u202f?<end>',
#  '<start>Je viendrai avec vous.<end>',
#  '<start>Je veux rester en vie.<end>',
#  '<start>Je suis maladroit.<end>',
#  '<start>Nous sommes ici.<end>',
#  "<start>J'ai une autre idée.<end>",
#  "<start>Elle ne t'appartient pas.<end>",
#  '<start>Je te le laisse.<end>',
#  '<start>Elles se sont couchées tard.<end>',
#  '<start>Sauvez Tom.<end>',
#  '<start>Y a-t-il une correspondance\u202f?<end>',
#  '<start>Ça me paraît intéressant\u202f!<end>',
#  '<start>Vous êtes trop poli.<end>',
#  '<start>Tu es trop naïve.<end>',
#  "<start>J'ai une chose à faire.<end>",
#  '<start>Vous dites toujours ça.<end>',
#  "<start>J'apprécie ceci.<end>",
#  '<start>Ma femme déteste les chats.<end>',
#  '<start>Où es-tu allée, exactement ?<end>',
#  '<start>Ils sont onéreux.<end>',
#  '<start>Ne raconte ceci à personne.<end>',
#  '<start>Ces animaux sont amicaux.<end>',
#  '<start>Va ouvrir la porte.<end>',
#  '<start>As-tu sommeil ?<end>',
#  '<start>Je compte sur ton aide.<end>',
#  "<start>C'est incroyable.<end>",
#  '<start>Arrête de me fixer !<end>',
#  '<start>Merci pour ton explication.<end>',
#  '<start>Ce serait bizarre.<end>',
#  "<start>J'étudie à la bibliothèque.<end>",
#  '<start>Celui qui hésite est perdu.<end>',
#  '<start>Peut-être la prochaine fois.<end>',
#  '<start>Laissez-moi appeler mon avocat !<end>',
#  '<start>Te joins-tu à nous ?<end>',
#  "<start>Tu n'étais jamais seul.<end>",
#  '<start>Qui protégiez-vous\xa0?<end>',
#  '<start>Je fus un peu déçue.<end>',
#  "<start>J'ai des plans.<end>",
#  '<start>Ça devrait le faire.<end>',
#  '<start>Elle pleura.<end>',
#  '<start>Viens me voir.<end>',
#  '<start>Le bébé pleure.<end>',
#  '<start>Où est mon argent ?<end>',
#  '<start>Son nouveau film est décevant.<end>',
#  "<start>J'aime les surprises.<end>",
#  '<start>Voyagez-vous beaucoup\u202f?<end>',
#  '<start>Il est après moi.<end>',
#  '<start>Je pense souvent à eux.<end>',
#  '<start>Je le recommande chaudement.<end>',
#  '<start>Avez-vous encore soif\xa0?<end>',
#  '<start>Il a une voix agréable.<end>',
#  '<start>Ce plan est infaillible.<end>',
#  "<start>Cela n'a rien de facultatif.<end>",
#  '<start>Tom tira la corde.<end>',
#  "<start>J'ai fait une expérience semblable.<end>",
#  "<start>Ils ont l'air de s'ennuyer.<end>",
#  "<start>J'ai été gracié.<end>",
#  '<start>Ce sont des espions.<end>',
#  "<start>C'est l'endroit idéal.<end>",
#  '<start>Il me faut partir.<end>',
#  '<start>Je viens vous aider.<end>',
#  '<start>Je cours tous les matins.<end>',
#  '<start>Es-tu malchanceuse\xa0?<end>',
#  "<start>Le devoir m'appelle.<end>",
#  '<start>Le travail est presque terminé.<end>',
#  '<start>Je suis dévoué.<end>',
#  '<start>Ce chemisier est en coton.<end>',
#  "<start>C'est plutôt cher.<end>",
#  "<start>J'ai été étonné.<end>",
#  '<start>Je ne le comprends pas.<end>',
#  '<start>Regarde les chaussures de Tom.<end>',
#  '<start>Tom est sur le toit.<end>',
#  '<start>Ce téléphone ne fonctionne pas.<end>',
#  '<start>Où est mon peigne ?<end>',
#  "<start>C'est un drôle de personnage.<end>",
#  '<start>Tom a confiance en moi.<end>',
#  "<start>Au début c'est difficile.<end>",
#  '<start>Savez-vous monter à cheval\u202f?<end>',
#  '<start>Je vous dois une explication.<end>',
#  '<start>Le type a raison.<end>',
#  '<start>Cette chaise est-elle libre ?<end>',
#  "<start>C'est plus que je n'escomptais.<end>",
#  '<start>Je me rappelle ce discours.<end>',
#  '<start>Êtes-vous dans la maison\xa0?<end>',
#  "<start>Qui d'autre y était\xa0?<end>",
#  '<start>Je lui dois $100.<end>',
#  '<start>Nous avons tous un prix.<end>',
#  "<start>J'étudie à la bibliothèque.<end>",
#  "<start>C'était le but.<end>",
#  '<start>Était-ce un écureuil ?<end>',
#  '<start>Tu dois être prudent.<end>',
#  "<start>T'as déjà fait ça ?<end>",
#  "<start>J'adore mon foyer.<end>",
#  '<start>Il est mouillé.<end>',
#  '<start>Nous vous voulions.<end>',
#  '<start>Quel cinglé !<end>',
#  "<start>Nous t'aimions.<end>",
#  "<start>J'aurais aimé être intelligent.<end>",
#  "<start>Il s'est beaucoup enivré.<end>",
#  '<start>Nous sommes juste fatiguées.<end>',
#  '<start>Il remonta une grosse truite.<end>',
#  '<start>Cette opération est simple.<end>',
#  '<start>Cette idée est controversée.<end>',
#  '<start>Ce serait merveilleux.<end>',
#  '<start>Il joue très bien.<end>',
#  '<start>Regarde attentivement.<end>',
#  '<start>En voudriez-vous une ?<end>',
#  '<start>Tom reste dîner.<end>',
#  '<start>Soyez polis mais fermes.<end>',
#  "<start>J'ai vraiment besoin de toi.<end>",
#  '<start>Pourquoi es-tu si arrogant ?<end>',
#  "<start>Tu as l'air d'un garçon.<end>",
#  '<start>Vous êtes incroyablement talentueuses.<end>',
#  '<start>Nos alliées sont faibles.<end>',
#  '<start>Ce travail paye plutôt bien.<end>',
#  "<start>J'aime jouer au football.<end>",
#  '<start>Ils ont menti.<end>',
#  "<start>Je n'aurais jamais autorisé cela.<end>",
#  "<start>C'est un problème social.<end>",
#  '<start>Personne ne possède la Lune.<end>',
#  "<start>Je ne comprends pas l'opéra.<end>",
#  '<start>Elle est occupée.<end>',
#  "<start>Tout le monde l'aime.<end>",
#  '<start>Il est motivé pour réussir.<end>',
#  '<start>Est-ce là votre vélo ?<end>',
#  '<start>Personne ne se trouvait là.<end>',
#  '<start>Marions-nous.<end>',
#  '<start>Tout est en place.<end>',
#  '<start>Tu as été sélectionné.<end>',
#  "<start>C'est un peu léger.<end>",
#  '<start>Vous devez essayer à nouveau.<end>',
#  '<start>Avez-vous reçu la lettre ?<end>',
#  '<start>Finis ton verre, maintenant !<end>',
#  "<start>Vous avez l'air nerveuse.<end>",
#  "<start>J'avais treize ans en 2003.<end>",
#  '<start>Je crois aux fantômes.<end>',
#  '<start>Personne ne vous a reconnu.<end>',
#  '<start>Tu es un merveilleux ami.<end>',
#  "<start>Comment vas-tu aujourd'hui\u202f?<end>",
#  '<start>Finissons-en !<end>',
#  "<start>Reste à l'écart.<end>",
#  '<start>Nous nous sommes embrassées.<end>',
#  "<start>J'aiderai.<end>",
#  '<start>Comment est le temps ?<end>',
#  '<start>Ferme le bureau à clé.<end>',
#  "<start>Je t'ai suivie.<end>",
#  '<start>Soyons raisonnables.<end>',
#  '<start>Ne gâche pas tes munitions.<end>',
#  "<start>C'est ce que j'ai demandé.<end>",
#  "<start>J'ai dormi comme un bébé.<end>",
#  "<start>J'ai immédiatement besoin de toi.<end>",
#  "<start>Tu es l'élue.<end>",
#  "<start>Tom refusa d'y aller.<end>",
#  '<start>Vous devez étudier plus assidument.<end>',
#  '<start>Elle accepta son cadeau.<end>',
#  '<start>Aimez-vous ses chansons ?<end>',
#  '<start>Tom a perdu son porte-monnaie.<end>',
#  '<start>On est potes hein ?<end>',
#  '<start>Je suis vraiment content.<end>',
#  "<start>Je n'aime pas les molosses.<end>",
#  '<start>Connaissez-vous mon mari ?<end>',
#  "<start>J'aimerais coopérer.<end>",
#  '<start>Je suis simplement fatiguée.<end>',
#  '<start>Êtes-vous blessée ?<end>',
#  '<start>Es-tu ici en vacances ?<end>',
#  '<start>Combien avez-vous apporté ?<end>',
#  '<start>Faites vos devoirs séance tenante.<end>',
#  '<start>Laquelle est ta tasse ?<end>',
#  '<start>Tom est toujours joyeux.<end>',
#  "<start>Je n'aime rien ici.<end>",
#  '<start>Nous le découvrirons bientôt.<end>',
#  "<start>Achetez-le-moi, s'il vous plaît.<end>",
#  '<start>Essayez plutôt ceci.<end>',
#  '<start>Qui est cette fille\u202f ?<end>',
#  '<start>Va voir le médecin.<end>',
#  "<start>N'es-tu pas gêné ?<end>",
#  '<start>Vous avez toute ma sympathie.<end>',
#  '<start>Je suis un peu occupé.<end>',
#  '<start>Tout le monde est endormi.<end>',
#  "<start>Tu n'y es pas autorisé.<end>",
#  '<start>Tom est multilingue.<end>',
#  "<start>C'est une blague.<end>",
#  "<start>C'est très onéreux\u202f!<end>",
#  '<start>Notre pommier est en fleurs.<end>',
#  '<start>Arrête de geindre.<end>',
#  '<start>Il arrêta la voiture.<end>',
#  '<start>Bas les armes\u202f!<end>',
#  '<start>Avez-vous demandé le prix ?<end>',
#  '<start>Où est Tom ?<end>',
#  '<start>Votre vie est en danger.<end>',
#  "<start>Je promets que j'appellerai.<end>",
#  "<start>J'ai été payée aujourd'hui.<end>",
#  "<start>J'ai fait cela d'innombrables fois.<end>",
#  '<start>Elle est bon écrivain.<end>',
#  '<start>Dis la vérité à Tom.<end>',
#  "<start>Elles s'ennuient.<end>",
#  '<start>Je ne fais que blaguer.<end>',
#  "<start>N'importe qui pourrait faire cela.<end>",
#  '<start>Il est pauvre, mais heureux.<end>',
#  "<start>Rends-toi à l'évidence.<end>",
#  "<start>L'appartement est en feu.<end>",
#  "<start>Nous n'avons pas commandé ça.<end>",
#  '<start>Vous ne me devez rien.<end>',
#  "<start>J'ai acheté une maison.<end>",
#  '<start>Ces cadeaux sont pour toi.<end>',
#  '<start>Tom demeure convaincu.<end>',
#  '<start>Je vais le buter.<end>',
#  '<start>Tom est innocent.<end>',
#  "<start>J'ai perdu confiance en Tom.<end>",
#  '<start>Vous me devez une excuse.<end>',
#  "<start>J'en ai eu besoin hier.<end>",
#  "<start>Il n'en sait encore rien.<end>",
#  "<start>On l'a échappé belle.<end>",
#  "<start>J'aime le cinéma.<end>",
#  "<start>J'ai appris ça de toi.<end>",
#  '<start>Puis-je venir chez vous ?<end>',
#  "<start>N'allume pas la bougie !<end>",
#  '<start>Elle semble malheureuse.<end>',
#  "<start>Nous avons de l'expérience.<end>",
#  '<start>Tom fait une vidéo.<end>',
#  '<start>Ces photos-là sont les siennes.<end>',
#  "<start>J'irai le chercher.<end>",
#  '<start>Je ne fume pas.<end>',
#  '<start>Les assiettes sont sales.<end>',
#  '<start>Tom est un monstre.<end>',
#  "<start>L'heure tourne.<end>",
#  '<start>Vous êtes extraverties.<end>',
#  '<start>Tu es arrivé trop tôt.<end>',
#  '<start>Tu vas me manquer.<end>',
#  '<start>Remettez-nous vos papiers.<end>',
#  '<start>Il a promis de l’épouser.<end>',
#  "<start>Je n'aime pas ton prénom.<end>",
#  '<start>Il vous faut être fort.<end>',
#  "<start>J'écris une chanson.<end>",
#  '<start>Le vent tourne.<end>',
#  '<start>Elles sont furieuses après vous.<end>',
#  '<start>Ces chaussures appartiennent à Tom.<end>',
#  '<start>Nous avons pris un taxi.<end>',
#  "<start>Hier, j'ai aidé mon père.<end>",
#  "<start>La décision ne m'appartient pas.<end>",
#  '<start>Ils ne faisaient que jouer.<end>',
#  "<start>C'est rafraîchissant.<end>",
#  '<start>Pourrais-tu annuler ma réservation\u202f?<end>',
#  '<start>Vers quelle heure\u202f?<end>',
#  "<start>Tu m'as refilé les foies.<end>",
#  "<start>Nous avons raté l'avion.<end>",
#  '<start>Ça sera délicat.<end>',
#  '<start>Tom aime encore son travail.<end>',
#  "<start>C'est un bel homme.<end>",
#  '<start>Ce sont les vôtres\u202f?<end>',
#  '<start>Vous plaisantez\u202f?<end>',
#  '<start>Nous sommes venus ensemble.<end>',
#  '<start>Prends tout !<end>',
#  '<start>Je déteste être photographié.<end>',
#  '<start>Sont-ils encore au lit ?<end>',
#  '<start>Merci de me recevoir.<end>',
#  '<start>Je vous prie de partir.<end>',
#  '<start>Pratiques-tu le recyclage ?<end>',
#  '<start>Elles parlaient de vous.<end>',
#  "<start>L'écureuil grimpa à l'arbre.<end>",
#  "<start>J'ai entendu quelqu'un crier.<end>",
#  "<start>Je dispose d'un dictionnaire.<end>",
#  '<start>Pourquoi êtes-vous seules ?<end>',
#  "<start>C'est en quelque sorte joli.<end>",
#  '<start>Enlève ton chapeau.<end>',
#  "<start>J'ai de sérieux doutes.<end>",
#  '<start>Juges-en par toi-même !<end>',
#  "<start>J'ai été contente.<end>",
#  "<start>C'est un bon chanteur.<end>",
#  '<start>Je vous suggère de partir.<end>',
#  '<start>Il respire avec difficulté.<end>',
#  '<start>Le bain est prêt.<end>',
#  "<start>Je vous suggère d'écouter attentivement.<end>",
#  '<start>Les toilettes sont là-bas.<end>',
#  "<start>La voiture a heurté l'arbre.<end>",
#  "<start>J'ai peur des araignées.<end>",
#  '<start>Je te souhaite bonne chance.<end>',
#  '<start>Merci pour votre recommandation.<end>',
#  '<start>Je suis innocente.<end>',
#  '<start>Arrives-tu à nous entendre ?<end>',
#  "<start>Qu'en est-il vraiment ?<end>",
#  '<start>Je dispose d’un couteau affûté.<end>',
#  '<start>Qui sait\u202f?<end>',
#  '<start>Ce couteau coupe bien.<end>',
#  '<start>On peut te remplacer.<end>',
#  '<start>Reprenez-vous\u202f!<end>',
#  '<start>Certaines des filles ont ri.<end>',
#  '<start>Dépêchez-vous, les filles !<end>',
#  "<start>C'était vraiment difficile.<end>",
#  '<start>Épargne-moi les détails macabres !<end>',
#  '<start>Veux-tu du café ?<end>',
#  '<start>Vous contrôlez votre destin.<end>',
#  '<start>Ne me le redemande pas.<end>',
#  "<start>M'apprécie-t-il ?<end>",
#  "<start>Ce n'est pas si bon.<end>",
#  "<start>Vous semblez triste aujourd'hui.<end>",
#  '<start>Vous êtes très habiles.<end>',
#  "<start>Qui est-ce que j'oublie ?<end>",
#  '<start>Qui peut le prévenir ?<end>',
#  '<start>Soyez miséricordieuses !<end>',
#  '<start>Ces maisons sont grandes.<end>',
#  '<start>Refaisons-la.<end>',
#  "<start>C'est ton préféré, non\xa0?<end>",
#  "<start>Il n'y a pas d'urgence.<end>",
#  '<start>Lisez ça maintenant !<end>',
#  '<start>Il prit son temps.<end>',
#  '<start>À dans trois mois.<end>',
#  "<start>C'est une blague sur vous.<end>",
#  "<start>J'ai attendu un mois.<end>",
#  '<start>Nous nous faisons des idées.<end>',
#  '<start>Mon cuir chevelu me démange.<end>',
#  "<start>Je n'ai pas fini.<end>",
#  '<start>Nous voulons plus de nourriture.<end>',
#  '<start>Quelle idée !<end>',
#  "<start>L'amour ne suffit pas.<end>",
#  '<start>Mon grand-père a un chien.<end>',
#  "<start>Ne t'excite pas tant !<end>",
#  "<start>Ça a l'air très intéressant.<end>",
#  '<start>Avez-vous une quelconque bière ?<end>',
#  '<start>Je partage ton avis.<end>',
#  '<start>Je suis honnête avec toi.<end>',
#  '<start>Je la vois ce soir.<end>',
#  '<start>Notre train a du retard.<end>',
#  '<start>Ne sous-estimez pas ma force.<end>',
#  "<start>Tom s'est séparé de Marie.<end>",
#  '<start>Nous avons survécu.<end>',
#  "<start>Il m'a tordu le bras.<end>",
#  '<start>Vous allez tous me manquer.<end>',
#  "<start>Ce n'est qu'une enfant.<end>",
#  "<start>N'y pensez plus !<end>",
#  '<start>Vous êtes trop maigres.<end>',
#  '<start>Assieds-toi juste là !<end>',
#  "<start>J'écris des poèmes.<end>",
#  "<start>T'en soucies-tu beaucoup ?<end>",
#  "<start>Tu t'es cassé le bras.<end>",
#  '<start>Aucun problème\u202f!<end>',
#  '<start>Cette pendule ne fonctionne pas.<end>',
#  '<start>Tom ne fit aucun commentaire.<end>',
#  '<start>On joue ensemble\u202f?<end>',
#  "<start>J'ai prévu quelque chose.<end>",
#  "<start>J'ai hâte de partir.<end>",
#  '<start>Il croit tout savoir.<end>',
#  '<start>Je me suis presque noyée.<end>',
#  '<start>Vous devez travailler ensemble.<end>',
#  '<start>Je suis touchée !<end>',
#  '<start>Je travaille dans cette entreprise.<end>',
#  '<start>Nous sommes ton dernier espoir.<end>',
#  "<start>Aujourd'hui, le ciel est clair.<end>",
#  '<start>Nous pourrions écrire un livre.<end>',
#  "<start>C'est incroyable, n'est-ce pas\xa0?<end>",
#  '<start>Les avions sont chers.<end>',
#  '<start>Ce siège est-il libre ?<end>',
#  '<start>Nous as-tu désignées ?<end>',
#  '<start>De quelles preuves disposez-vous ?<end>',
#  "<start>C'est un fait.<end>",
#  '<start>Cette fois sera différente.<end>',
#  '<start>Vous êtes fort compréhensifs.<end>',
#  '<start>Laissez-moi tranquille\u202f!<end>',
#  '<start>Les deux alternatives sont envisageables.<end>',
#  "<start>Quiconque m'entend-il ?<end>",
#  "<start>J'aime les westerns.<end>",
#  '<start>Tu es très courageuse.<end>',
#  '<start>Ils vont le tenter.<end>',
#  '<start>Elle a été à Paris.<end>',
#  '<start>En été, je nage.<end>',
#  "<start>Elles avaient l'air toutes satisfaites.<end>",
#  "<start>Ça s'est rafraîchi.<end>",
#  '<start>Nous voulons gagner.<end>',
#  "<start>Vous avez l'air déprimées.<end>",
#  '<start>Je fis une liste.<end>',
#  '<start>Il faut que tu cesses.<end>',
#  '<start>Qui est au volant\u202f?<end>',
#  '<start>Tout le monde ment.<end>',
#  '<start>Leur maîtresse les loua.<end>',
#  "<start>J'irai voir.<end>",
#  '<start>Ils parlent.<end>',
#  "<start>Qu'a dit le médecin ?<end>",
#  "<start>Le reste n'importe pas.<end>",
#  "<start>Il l'aime toujours.<end>",
#  '<start>Demain est mon anniversaire.<end>',
#  '<start>Viens avec moi maintenant.<end>',
#  '<start>Pas de nouvelles, bonnes nouvelles.<end>',
#  '<start>Je pars au boulot.<end>',
#  '<start>Ils ont été victorieux.<end>',
#  "<start>J'aime le rock.<end>",
#  '<start>Où irez-vous ?<end>',
#  '<start>Ce sandwich est bon.<end>',
#  '<start>Passe un bon week-end\u202f!<end>',
#  "<start>Elle s'est spécialisée en histoire.<end>",
#  '<start>Il garda la fenêtre fermée.<end>',
#  '<start>Mettez-le où bon vous semble.<end>',
#  '<start>Faisons quelque chose.<end>',
#  '<start>Tom a perdu espoir.<end>',
#  '<start>Merci pour ton aide.<end>',
#  '<start>Elle a modifié ses plans.<end>',
#  "<start>Aucun calendrier n'a été fixé.<end>",
#  '<start>Les oiseaux construisent des nids.<end>',
#  '<start>Ne vous approchez pas davantage.<end>',
#  "<start>C'est très proche.<end>",
#  '<start>Ce steak est très juteux.<end>',
#  "<start>Va embrasser quelqu'un d'autre !<end>",
#  '<start>Combien furent blessés ?<end>',
#  '<start>Rendez-vous à 14\xa0h\xa030.<end>',
#  '<start>Est-ce vraiment nécessaire\xa0?<end>',
#  "<start>J'étais pétrifié.<end>",
#  '<start>Nous fîmes de notre mieux.<end>',
#  "<start>Qu'est la pensée critique ?<end>",
#  '<start>Ne jetez pas cette tasse.<end>',
#  '<start>La journée a été épuisante.<end>',
#  '<start>Est-ce réalisable\xa0?<end>',
#  "<start>C'est impossible à décrire.<end>",
#  '<start>Nous irons petit-déjeuner à 6h30.<end>',
#  '<start>Il me donna une pomme.<end>',
#  "<start>C'est du charabia.<end>",
#  '<start>Un instant...<end>',
#  '<start>Attrape ce livre pour moi.<end>',
#  '<start>Tu dois être hardi !<end>',
#  '<start>Échauffez-vous !<end>',
#  '<start>Ta migraine est passée ?<end>',
#  "<start>Il décida de l'épouser.<end>",
#  '<start>Ouvre le paquet.<end>',
#  "<start>Lis ça d'abord.<end>",
#  "<start>L'avez-vous mesuré ?<end>",
#  '<start>Elle est très mignonne.<end>',
#  '<start>Je comprends complètement.<end>',
#  '<start>Il est ouvert et confiant.<end>',
#  "<start>Elle l'a immédiatement reconnu.<end>",
#  '<start>Le public commença à rire.<end>',
#  "<start>Il n'a pas d'argent.<end>",
#  '<start>Soyez aussi rapide que possible.<end>',
#  "<start>La situation s'est stabilisée.<end>",
#  '<start>Es-tu venu ici depuis\u202f?<end>',
#  '<start>Êtes-vous jalouses ?<end>',
#  '<start>Nous sommes détendues.<end>',
#  "<start>C'était vraiment sombre.<end>",
#  "<start>Tom est-il à l'abri ?<end>",
#  '<start>Faites juste de votre mieux.<end>',
#  '<start>Pourquoi rirais-je ?<end>',
#  '<start>Je suis un peu occupée.<end>',
#  '<start>Fais ton boulot.<end>',
#  '<start>Tu dois respecter tes aînés.<end>',
#  '<start>Fais bon voyage !<end>',
#  "<start>Qu'as-tu fais ?<end>",
#  '<start>Mâche bien ta nourriture.<end>',
#  '<start>Tom adore les évènements sportifs.<end>',
#  "<start>J'ai cessé de rire.<end>",
#  '<start>Tom est un client.<end>',
#  "<start>C'est très onéreux\u202f!<end>",
#  '<start>Commençons par nous présenter.<end>',
#  '<start>Je contractai un rhume.<end>',
#  '<start>La connaissez-vous ?<end>',
#  '<start>Vous êtes trop maigrichonne.<end>',
#  "<start>Personne ne l'a vu.<end>",
#  '<start>Tom a pâli.<end>',
#  '<start>Sois poli mais ferme.<end>',
#  '<start>Je me sentis apeurée.<end>',
#  '<start>En êtes-vous certaines ?<end>',
#  "<start>C'est une célèbre chanteuse.<end>",
#  "<start>N'éteignez pas votre ordinateur.<end>",
#  "<start>T'ai-je surpris ?<end>",
#  '<start>Elles ont eu une discussion.<end>',
#  '<start>Le marché est complètement saturé.<end>',
#  '<start>Soyez discrètes !<end>',
#  '<start>Ce serait vraiment génial.<end>',
#  '<start>Laisse-moi les voir.<end>',
#  '<start>Je vais regarder la télé.<end>',
#  '<start>Il nous a vendus.<end>',
#  '<start>Il me faut un verre.<end>',
#  '<start>Personne ne peut vous aider.<end>',
#  '<start>De quoi parles-tu ?<end>',
#  '<start>Je suis habitué.<end>',
#  "<start>N'obéis pas à cet homme.<end>",
#  '<start>Ils sont tous les mêmes.<end>',
#  "<start>La rumeur s'est répandue rapidement.<end>",
#  "<start>Qu'est-ce qui causerait ça ?<end>",
#  "<start>J'ai quelque chose pour toi.<end>",
#  '<start>Il apprécie de dormir.<end>',
#  '<start>Je le rendrai.<end>',
#  '<start>Le souper est presque prêt.<end>',
#  '<start>Elles nous ont trouvées.<end>',
#  '<start>Rien ne rend Tom heureux.<end>',
#  '<start>Dites-moi où est Tom.<end>',
#  '<start>Laisse-nous sortir !<end>',
#  "<start>Belle journée, n'est-ce pas\u202f?<end>",
#  "<start>À tout à l'heure\u202f!<end>",
#  '<start>Nous nous en sommes assurées.<end>',
#  '<start>Suis-je gros ?<end>',
#  "<start>J'adore les fêtes.<end>",
#  '<start>Je veux que lui parte.<end>',
#  '<start>Sommes-nous prêtes ?<end>',
#  '<start>Nous ne sommes pas assurées.<end>',
#  '<start>Ouvre les fenêtres !<end>',
#  '<start>Tom aime jouer au football.<end>',
#  '<start>Cette maison est à moi.<end>',
#  '<start>La demande a été acceptée.<end>',
#  '<start>Vous êtes courtoises.<end>',
#  '<start>Débranchez la prise.<end>',
#  '<start>Elle a aimé ça.<end>',
#  '<start>Je travaillais tard.<end>',
#  "<start>L'avion a accéléré.<end>",
#  '<start>Le changement est important.<end>',
#  "<start>C'est urgent.<end>",
#  '<start>Avez-vous entendu ça ?<end>',
#  "<start>Tom n'a jamais rencontré Marie.<end>",
#  '<start>Cet endroit est toujours bondé.<end>',
#  "<start>Ce n'est vraiment pas important.<end>",
#  "<start>La nouvelle l'a rendue triste.<end>",
#  "<start>C'est rigolo de voyager.<end>",
#  "<start>J'aime ce magasin.<end>",
#  "<start>Aucune d'elles n'a l'air surprise.<end>",
#  '<start>Je me sens en sécurité.<end>',
#  '<start>Je suis femme au foyer.<end>',
#  "<start>J'ai la gueule de bois.<end>",
#  '<start>Parle un tantinet plus fort.<end>',
#  "<start>Cesse d'être idiot !<end>",
#  "<start>Voici l'une de mes préférées.<end>",
#  '<start>Il me chuchota quelque chose.<end>',
#  "<start>C'est une erreur.<end>",
#  "<start>C'est incroyablement puissant.<end>",
#  '<start>Je jouais ici.<end>',
#  '<start>La musique te plaît\u202f?<end>',
#  '<start>Lundi était un jour venteux.<end>',
#  '<start>Thomas est devenu père.<end>',
#  "<start>Ta prophétie s'est réalisée.<end>",
#  "<start>Dis-m'en davantage.<end>",
#  "<start>Personne n'est venu aujourd'hui.<end>",
#  '<start>Est-ce si terrible ?<end>',
#  "<start>J'ai perdu ton numéro.<end>",
#  '<start>Tom travaille toute la nuit.<end>',
#  '<start>Laisse-moi vérifier mon portefeuille !<end>',
#  '<start>Cette chambre est calme.<end>',
#  '<start>Tu me dois un bisou.<end>',
#  "<start>C'est vraiment surprenant !<end>",
#  "<start>J'ai besoin d'une chemise propre.<end>",
#  '<start>Êtes-vous las ?<end>',
#  '<start>Pourquoi tout ce drame ?<end>',
#  '<start>Elle a des yeux attirants.<end>',
#  "<start>J'ai appris un nouveau tour.<end>",
#  '<start>Ça fonctionne.<end>',
#  '<start>Dites-moi où vous êtes allées.<end>',
#  "<start>J'ai un télescope.<end>",
#  '<start>Tu as franchi la ligne.<end>',
#  '<start>Laisse-moi attraper mon sac !<end>',
#  "<start>C'était vraiment nul.<end>",
#  '<start>Donne-moi dix minutes.<end>',
#  '<start>Pourquoi Tom est-il ici\xa0?<end>',
#  "<start>Soyez poli s'il vous plaît.<end>",
#  '<start>As-tu un peigne ?<end>',
#  "<start>J'admire le dévouement de Tom.<end>",
#  '<start>La situation se détériore.<end>',
#  '<start>Tom et Maria étaient jeunes.<end>',
#  '<start>Vous ne serez pas intéressés.<end>',
#  '<start>Je suis fiancé avec elle.<end>',
#  '<start>La chance est contre moi.<end>',
#  '<start>Reviens ici !<end>',
#  '<start>Je ne vais pas bien.<end>',
#  '<start>Tom nous enseigne le français.<end>',
#  "<start>Il s'est envolé pour Paris.<end>",
#  "<start>Je n'ai pas trop confiance.<end>",
#  "<start>J'ai échoué.<end>",
#  "<start>J'espère qu'elles m'ont appréciée.<end>",
#  "<start>Tom ne fit rien d'autre.<end>",
#  "<start>J'ai vu le dossier.<end>",
#  '<start>Hé, ouvre la porte.<end>',
#  '<start>Pourriez-vous vérifier les pneus\xa0?<end>',
#  '<start>Presse-toi, je te prie !<end>',
#  '<start>Mon pantalon est mouillé.<end>',
#  "<start>J'en suis heureux.<end>",
#  '<start>Puis-je le toucher ?<end>',
#  '<start>Il alluma les cierges.<end>',
#  '<start>Raconte-nous tous les commérages !<end>',
#  '<start>Personne ne nous écoutait.<end>',
#  "<start>Ce n'est pas sécurisé.<end>",
#  '<start>Ceci est votre pays.<end>',
#  "<start>Pourquoi m'aides-tu\xa0?<end>",
#  '<start>Vous êtes toutes pareilles.<end>',
#  '<start>Les possibilités sont infinies.<end>',
#  "<start>C'était la nôtre.<end>",
#  "<start>J'ai adoré ça.<end>",
#  "<start>Attendez jusqu'à six heures.<end>",
#  '<start>Je ne suis pas méchante.<end>',
#  '<start>Tom a repoussé cette pensée.<end>',
#  '<start>Laissez-le partir !<end>',
#  "<start>Qu'avons-nous obtenu ?<end>",
#  '<start>Je suis raisonnable.<end>',
#  "<start>Ce n'est vraiment plus nécessaire.<end>",
#  "<start>J'aime mes amis.<end>",
#  '<start>Tout était difficile.<end>',
#  '<start>Quand avez-vous trouvé ?<end>',
#  '<start>Descends de là !<end>',
#  '<start>Je vis confortablement.<end>',
#  '<start>Sors de mon siège !<end>',
#  "<start>L'eau s'est muée en glace.<end>",
#  '<start>Je suis ta sœur.<end>',
#  '<start>As-tu acheté des tomates ?<end>',
#  '<start>Le magasin était relativement vide.<end>',
#  "<start>C'est totalement justifié.<end>",
#  '<start>Je suis ruinée.<end>',
#  "<start>Ce n'était pas mon idée.<end>",
#  '<start>Il fait bon ce soir.<end>',
#  '<start>Je me sens très coupable.<end>',
#  "<start>J'aurai besoin de votre aide.<end>",
#  '<start>Vous avez toujours une chance.<end>',
#  '<start>Nous nous amusons tous.<end>',
#  '<start>Je suis grassouillette.<end>',
#  '<start>A-t-elle dit ça ?<end>',
#  '<start>Ne le jette pas !<end>',
#  '<start>Travaille lentement !<end>',
#  '<start>On mangera sur le chemin.<end>',
#  '<start>Tu as de beaux cheveux.<end>',
#  "<start>C'était étonnant.<end>",
#  '<start>Ma connexion internet est lente.<end>',
#  "<start>J'aime tes boucles d'oreilles.<end>",
#  "<start>C'est un baratineur.<end>",
#  '<start>Il est héroïno-dépendant.<end>',
#  '<start>Votre français est bon.<end>',
#  "<start>T'ai-je blessé ?<end>",
#  '<start>Nous avions vraiment froid.<end>',
#  '<start>Je suis responsable de ça.<end>',
#  "<start>Tout le monde l'aime.<end>",
#  '<start>Elles veulent me tuer.<end>',
#  '<start>Voici ton verre !<end>',
#  '<start>Il fera très chaud demain.<end>',
#  "<start>Qui te l'a donné ?<end>",
#  '<start>Reste malin !<end>',
#  '<start>Voilà les billets.<end>',
#  '<start>Elle bougea mes vêtements.<end>',
#  "<start>C'est une lettre importante.<end>",
#  "<start>Ils moururent l'un après l'autre.<end>",
#  '<start>Sont-ils des flics ?<end>',
#  '<start>Quelle est votre explication\xa0?<end>',
#  '<start>Nous nous sommes assis devant.<end>',
#  "<start>Vous n'êtes pas si intéressantes.<end>",
#  '<start>Tom aime jouer au tennis.<end>',
#  '<start>С’est vraiment gentil à vous.<end>',
#  '<start>Tom aime la country.<end>',
#  '<start>Vous êtes toutes contre moi.<end>',
#  "<start>Je n'ai pas demandé d'aide.<end>",
#  "<start>C'est une maison bleue.<end>",
#  "<start>J'ai un frère.<end>",
#  '<start>Les vacances sont déjà finies.<end>',
#  "<start>Je n'ai pas voté.<end>",
#  "<start>Je n'ai pas d'objection.<end>",
#  '<start>Elle dort avec deux coussins.<end>',
#  '<start>Appellez les flics !<end>',
#  "<start>Je te rejoindrai à l'extérieur.<end>",
#  "<start>Je n'ai rien vu.<end>",
#  '<start>Je fais des progrès.<end>',
#  '<start>Es-tu assuré\xa0?<end>',
#  "<start>J'ai adoré la pièce.<end>",
#  '<start>Puis-je emprunter ce livre\u202f?<end>',
#  "<start>C'est un bon à rien.<end>",
#  "<start>J'aime les récits.<end>",
#  '<start>Venez, je vous prie.<end>',
#  '<start>Jouons au baseball.<end>',
#  '<start>Nous avons une date butoir.<end>',
#  "<start>N'oublie pas de voter !<end>",
#  '<start>Il trépassa dans son lit.<end>',
#  '<start>Je veux un médecin.<end>',
#  '<start>Veuillez abaisser la vitre !<end>',
#  '<start>Apportez-moi le journal.<end>',
#  '<start>Êtes-vous sûre\u202f?<end>',
#  "<start>J'attendrai dans le gymnase.<end>",
#  '<start>Elles ont payé séparément.<end>',
#  '<start>En prends-tu conscience ?<end>',
#  "<start>Je n'ai voté pour personne.<end>",
#  "<start>C'est mon amie.<end>",
#  '<start>Aimes-tu le base-ball\xa0?<end>',
#  '<start>Il est venu chez moi.<end>',
#  '<start>Thomas est OK maintenant.<end>',
#  '<start>Vous me flattez.<end>',
#  '<start>Nous sommes plutôt occupées, ici.<end>',
#  '<start>Il traversa la rivière.<end>',
#  '<start>Il est accro aux méthamphétamines.<end>',
#  '<start>Ce chapeau est à vous.<end>',
#  '<start>Le commandant refusa de négocier.<end>',
#  '<start>Félicitations pour ton anniversaire.<end>',
#  '<start>Nous apprécions Tom.<end>',
#  '<start>Elle a visé la cible.<end>',
#  '<start>Le bureau est vide.<end>',
#  '<start>Tu aimes vivre dangereusement ?<end>',
#  '<start>Il a dormi une heure.<end>',
#  '<start>Ils étaient tous deux saouls.<end>',
#  "<start>Ça a l'air insensé.<end>",
#  '<start>Il disait la vérité.<end>',
#  "<start>Il a changé d'avis.<end>",
#  '<start>Ce parapluie ressemble au mien.<end>',
#  "<start>Je bois de l'eau.<end>",
#  '<start>Mets-le là, pas ici !<end>',
#  '<start>Où sont mes enfants\xa0?<end>',
#  "<start>Je t'ai toujours aimé.<end>",
#  '<start>Est-ce un travail difficile ?<end>',
#  '<start>Avez-vous jamais été seule ?<end>',
#  "<start>C'est certainement possible.<end>",
#  '<start>Tom était manifestement offensé.<end>',
#  '<start>Dublin est en Irlande.<end>',
#  '<start>Vous êtes très grandes.<end>',
#  "<start>J'étais tellement déçu.<end>",
#  '<start>Tu aimes Boston, non ?<end>',
#  '<start>Les bois brûlent facilement.<end>',
#  '<start>Pioche une carte !<end>',
#  '<start>Un piano coûte cher.<end>',
#  '<start>Il vit seul.<end>',
#  '<start>Tout a parfaitement fonctionné.<end>',
#  '<start>La partie est presque terminée.<end>',
#  '<start>Tout est pour vous.<end>',
#  '<start>La puissance fait le droit.<end>',
#  "<start>Je pense qu'ils t'apprécient.<end>",
#  '<start>Regardez-nous.<end>',
#  '<start>Ils ont discuté du problème.<end>',
#  '<start>Vous êtes en sécurité.<end>',
#  '<start>Tu devrais faire attention.<end>',
#  "<start>Je m'en sors.<end>",
#  '<start>Vous êtes toujours vivante.<end>',
#  '<start>Tu es presque mort.<end>',
#  '<start>Je partage vraiment tes sentiments.<end>',
#  "<start>C'était fini.<end>",
#  "<start>On l'a fait pleurer.<end>",
#  "<start>Tu as l'air différent.<end>",
#  '<start>Du café, je te prie.<end>',
#  "<start>Il m'a appelé un taxi.<end>",
#  "<start>C'est ce qu'il a peint.<end>",
#  "<start>Sors de l'eau !<end>",
#  '<start>Un cri brisa le silence.<end>',
#  "<start>J'ai les chocottes.<end>",
#  '<start>Je suis étudiant.<end>',
#  '<start>Êtes-vous japonais\u202f?<end>',
#  '<start>Quelles sont vos mensurations ?<end>',
#  '<start>Où êtes-vous nées ?<end>',
#  '<start>Il sait lire et écrire.<end>',
#  '<start>Où nous envoient-elles ?<end>',
#  '<start>Tous les hommes naissent égaux.<end>',
#  '<start>Aucun point ne fut nécessaire.<end>',
#  '<start>Êtes-vous blessé\xa0?<end>',
#  "<start>Je suis dépourvu d'expérience.<end>",
#  '<start>Ils ont voté.<end>',
#  '<start>Je suis vraiment choquée.<end>',
#  "<start>Je n'ai pas aimé ça.<end>",
#  '<start>Tom est bûcheron.<end>',
#  '<start>À votre santé !<end>',
#  "<start>C'est pour toi.<end>",
#  '<start>Où nagent-ils ?<end>',
#  '<start>Elles dirent non.<end>',
#  "<start>J'ai été mal compris.<end>",
#  '<start>Trois semaines sont passées.<end>',
#  "<start>Ce n'est pas une menteuse.<end>",
#  "<start>Je n'ai pas oublié.<end>",
#  "<start>Il fait beau aujourd'hui.<end>",
#  '<start>Ils ne viennent pas.<end>',
#  '<start>Ne soyez pas mesquin !<end>',
#  "<start>Tom n'aime pas chanter.<end>",
#  '<start>Il pleut ici.<end>',
#  '<start>Est-ce chaud\xa0?<end>',
#  '<start>Elles sont toutes fausses.<end>',
#  "<start>Je n'en avais aucune idée.<end>",
#  '<start>La police arrêta un homme.<end>',
#  '<start>Je préfère rester ici.<end>',
#  '<start>La lune est là.<end>',
#  '<start>Elle est très grande.<end>',
#  '<start>Bien calculé !<end>',
#  "<start>Je ne t'ai jamais menti.<end>",
#  "<start>J'aime les éléphants.<end>",
#  "<start>J'insiste sur cela.<end>",
#  '<start>La vérité importe-t-elle ?<end>',
#  "<start>Elle a vraiment l'air fatiguée.<end>",
#  "<start>Il n'a pas changé d'avis.<end>",
#  '<start>Prenez un numéro !<end>',
#  "<start>Tom sort avec quelqu'un.<end>",
#  '<start>Je respecte toujours les règles.<end>',
#  "<start>J'ai perdu tout mon argent.<end>",
#  '<start>Vous pouvez y arriver.<end>',
#  '<start>Avez-vous tiré sur Tom\xa0?<end>',
#  "<start>Tom m'a quittée.<end>",
#  '<start>Vous êtes doués pour ça.<end>',
#  '<start>Elle chantait assez bien.<end>',
#  '<start>En voudrais-tu ?<end>',
#  "<start>Dieu créa l'univers.<end>",
#  "<start>Qu'y a-t-il devant vous ?<end>",
#  '<start>Il est dur à cuire.<end>',
#  "<start>Vous n'êtes pas grosses.<end>",
#  '<start>Fais bon voyage !<end>',
#  '<start>Nous nous reverrons.<end>',
#  '<start>Redites ça !<end>',
#  "<start>C'est une possibilité.<end>",
#  "<start>J'ai des plans.<end>",
#  '<start>Quelle nuit !<end>',
#  '<start>Penses-tu que ça marche ?<end>',
#  '<start>Nous devons saisir cette chance.<end>',
#  '<start>Ai-je manqué la bifurcation ?<end>',
#  "<start>Je n'entends pas d'aboiement.<end>",
#  "<start>J'admets être fatigué.<end>",
#  "<start>Elle promit de l'épouser.<end>",
#  "<start>Vous semblez distrait aujourd'hui.<end>",
#  "<start>Je l'ai brûlée.<end>",
#  '<start>Pourquoi vous ont-ils recruté ?<end>',
#  '<start>Avez-vous fini votre repas ?<end>',
#  '<start>Le mien est totalement différent.<end>',
#  '<start>Je me sens tellement impuissant.<end>',
#  '<start>Tom a allumé les bougies.<end>',
#  '<start>Nous annulâmes le mariage.<end>',
#  '<start>Vous êtes très marrants.<end>',
#  '<start>Nous retournons à Boston.<end>',
#  "<start>Il n'a plus de force.<end>",
#  '<start>Je pouvais marcher.<end>',
#  '<start>Je crois aux miracles.<end>',
#  '<start>Je sais.<end>',
#  '<start>Il ira également.<end>',
#  '<start>Regardez-vous attentivement ?<end>',
#  '<start>Ça a été très amusant.<end>',
#  '<start>La guerre est mauvaise.<end>',
#  '<start>Êtes-vous pressés ?<end>',
#  '<start>Avec quoi joues-tu\xa0?<end>',
#  '<start>Les chaussures sont usées.<end>',
#  "<start>C'est mon argent.<end>",
#  '<start>Je vais me changer.<end>',
#  "<start>J'ai surmonté ça.<end>",
#  "<start>Tout avait l'air agréable.<end>",
#  "<start>Je pense que j'avais tort.<end>",
#  '<start>Je les ai rencontrées.<end>',
#  '<start>Il travaille de longues heures.<end>',
#  "<start>Elle l'aime encore.<end>",
#  '<start>Voulez-vous partir\u202f?<end>',
#  "<start>Je pense que c'est indéniable.<end>",
#  "<start>Il m'en doit une.<end>",
#  '<start>Une minute compte soixante secondes.<end>',
#  '<start>Ça paraît vraiment bon.<end>',
#  "<start>Il me toucha l'épaule.<end>",
#  '<start>Te sens-tu seule\u202f?<end>',
#  '<start>Tes œufs refroidissent.<end>',
#  '<start>Tom est paresseux.<end>',
#  '<start>Êtes-vous toutes deux folles ?<end>',
#  "<start>Quand cela s'est-il produit\u202f?<end>",
#  "<start>C'est ma destinée.<end>",
#  "<start>J'ai besoin d'une escorte.<end>",
#  '<start>Que lis-tu ?<end>',
#  "<start>Quelqu'un est-il avec vous ?<end>",
#  '<start>Il craint la mort.<end>',
#  '<start>Il leva la main.<end>',
#  "<start>C'était sucré.<end>",
#  "<start>Vous n'êtes pas en retard.<end>",
#  '<start>Tu peux compter sur lui.<end>',
#  '<start>Il se déteste.<end>',
#  '<start>Je me sentais très heureux.<end>',
#  '<start>Je conduis partout.<end>',
#  '<start>Je me sens seul.<end>',
#  "<start>C'est un magnifique dessin.<end>",
#  '<start>Vous allez rater le train.<end>',
#  "<start>Il n'en reste que trois.<end>",
#  '<start>Tu dis toujours ça.<end>',
#  "<start>J'ai juste fini de déjeuner.<end>",
#  "<start>Pars-tu aujourd'hui ?<end>",
#  '<start>Je prendrai soin de celles-là.<end>',
#  '<start>Restez dans la maison.<end>',
#  "<start>Qui l'aide ?<end>",
#  "<start>Il faut que j'y retourne.<end>",
#  '<start>Quels médicaments prenez-vous\xa0?<end>',
#  '<start>Je suis ton partenaire.<end>',
#  '<start>Elle me prépara un gâteau.<end>',
#  '<start>Il est précieux pour nous.<end>',
#  "<start>Il m'a laissé les clés.<end>",
#  '<start>Le boucher hacha la viande.<end>',
#  '<start>Amenez vos enfants avec vous.<end>',
#  '<start>Voilà un livre, ici.<end>',
#  '<start>As-tu un natel\u202f?<end>',
#  '<start>Ça vient de paraître.<end>',
#  '<start>Avez-vous aimé ce livre\xa0?<end>',
#  "<start>J'ai vérifié partout.<end>",
#  '<start>Je regardais juste aux alentours.<end>',
#  '<start>Tu me bloques la vue.<end>',
#  "<start>J'ai entendu hurler.<end>",
#  '<start>Je déteste ma colocataire.<end>',
#  "<start>Quel temps fait-il aujourd'hui\xa0?<end>",
#  "<start>J'ai une chemise verte.<end>",
#  '<start>Nous serons tous là.<end>',
#  '<start>As-tu envie de danser ?<end>',
#  '<start>Puis-je en avoir une ?<end>',
#  '<start>Je me sens honteuse.<end>',
#  '<start>Êtes-vous en bonne santé ?<end>',
#  '<start>Tu es très attirante.<end>',
#  '<start>Quel mauvais film\xa0!<end>',
#  '<start>Tom plaisante.<end>',
#  '<start>Mets-toi debout !<end>',
#  "<start>C'est l'heure de déjeuner.<end>",
#  '<start>Vous êtes fascinant.<end>',
#  '<start>Je ne comprends vraiment rien.<end>',
#  '<start>Je dormirai par terre.<end>',
#  '<start>Les circonstances était alors différentes.<end>',
#  '<start>Ils ne resteront pas longtemps.<end>',
#  "<start>Tu es l'élu.<end>",
#  "<start>C'est difficile à dire.<end>",
#  "<start>Je ne m'en souviens plus.<end>",
#  '<start>Vous êtes le meilleur.<end>',
#  "<start>J'ai pris une mauvaise décision.<end>",
#  '<start>La porte est verrouillée.<end>',
#  '<start>Elle travaille dur.<end>',
#  "<start>Nous n'avons rien vu.<end>",
#  '<start>Ta mère est très jeune.<end>',
#  "<start>J'ai vraiment aimé ce film.<end>",
#  '<start>Nous pouvons peut-être réparer ceci.<end>',
#  '<start>Il est un peu jaloux.<end>',
#  '<start>Ma mère était en larmes.<end>',
#  "<start>Qu'avez-vous ressenti ?<end>",
#  "<start>J'adore Noël.<end>",
#  '<start>Tom était désagréable avec Marie.<end>',
#  '<start>Attrape-moi si tu peux.<end>',
#  "<start>Vous devriez aller à l'école.<end>",
#  '<start>Tu es incorrigible.<end>',
#  "<start>C'est grand !<end>",
#  "<start>Il va a l'école.<end>",
#  "<start>T'as compris, désormais ?<end>",
#  "<start>Vous n'êtes pas invincible.<end>",
#  '<start>Tu es un tocard.<end>',
#  '<start>Procédez avec prudence.<end>',
#  "<start>J'avais besoin de vous rencontrer.<end>",
#  '<start>Je ne peux te protéger.<end>',
#  '<start>Je vous guiderai.<end>',
#  '<start>Ça pourrait ne pas suffire.<end>',
#  '<start>Écrivez-vous en français\xa0?<end>',
#  "<start>Je n'ai pas d'enfants.<end>",
#  '<start>Papa gère le magasin.<end>',
#  "<start>Je t'ai commandé une bière.<end>",
#  "<start>Elles étaient fatiguées d'attendre.<end>",
#  "<start>Ils ont l'air détendus.<end>",
#  '<start>Taillons la route !<end>',
#  "<start>Je l'ai senti.<end>",
#  "<start>C'est assez mauvais.<end>",
#  '<start>Les meilleurs coiffeurs sont gays.<end>',
#  "<start>Elle prit soin de l'enfant.<end>",
#  '<start>Où allons-nous cette nuit\u202f?<end>',
#  '<start>Vous allez vous remettre.<end>',
#  "<start>Il regrettait d'avoir été paresseux.<end>",
#  "<start>J'ai brûlé le gâteau.<end>",
#  "<start>Pourquoi n'entrez-vous pas ?<end>",
#  '<start>Laisse tomber.<end>',
#  '<start>Êtes-vous nés là-bas ?<end>',
#  "<start>J'apprends l'anglais.<end>",
#  '<start>Tom parait jaloux.<end>',
#  '<start>Les lapins savent-ils nager ?<end>',
#  '<start>Cette chienne mord.<end>',
#  '<start>Elle a allumé la télé.<end>',
#  ...]

# %%
french_valid = get_data(list(valid['French words/sentences']))
english_valid = get_data(list(valid['English words/sentences']))

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Tokenizing and padding input language (French)
fre_token = Tokenizer(filters='', lower=False)
fre_token.fit_on_texts(french_train)
fre_tokenized = fre_token.texts_to_sequences(french_train)
fre_padded = pad_sequences(fre_tokenized, padding='post')

# Tokenizing and padding target language (English)
eng_token = Tokenizer(filters='', lower=False)
eng_token.fit_on_texts(english_train)
eng_tokenized = eng_token.texts_to_sequences(english_train)
eng_padded = pad_sequences(eng_tokenized, padding='post')

# %%
# Assuming fre_token and end_token are Tokenizer objects that have been fit on the respective datasets
# fre_token.word_index is a dictionary mapping words to their integer index in French
# end_token.word_index is a dictionary mapping words to their integer index in English

# Number of unique tokens in the output (French) language
num_op_tokens = len(fre_token.word_index)

# Number of unique tokens in the input (English) language
num_ip_tokens = len(eng_token.word_index)

# Assuming fre_padded and eng_padded are padded sequences of your tokenized text data
# fre_padded.shape[1] gives the maximum length of the padded sequences in French
# eng_padded.shape[1] gives the maximum length of the padded sequences in English

# Maximum length of sentence in the output (French) language
max_len_op = fre_padded.shape[1]

# Maximum length of sentence in the input (English) language
max_len_ip = eng_padded.shape[1]

# %%
num_op_tokens
# Out:
# 19469

# %%
num_ip_tokens
# Out:
# 11436

# %%
max_len_op
# Out:
# 5

# %%
max_len_ip
# Out:
# 5

# %%
french_train[0]
# Out:
# '<start>Il pleuvait.<end>'

# %%
fre_padded[0]
# Out:
# array([   4, 3688,    0,    0,    0], dtype=int32)

# %% [markdown]
# # **K-Text**

# %%
pip install ktext
# Out:
# Requirement already satisfied: ktext in /usr/local/lib/python3.10/dist-packages (0.34)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ktext) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ktext) (1.11.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from ktext) (1.16.0)
# Requirement already satisfied: pandas>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from ktext) (2.0.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ktext) (6.0.1)
# Requirement already satisfied: pathos in /usr/local/lib/python3.10/dist-packages (from ktext) (0.3.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from ktext) (1.0.8)
# Requirement already satisfied: msgpack-numpy in /usr/local/lib/python3.10/dist-packages (from ktext) (0.4.8)
# Requirement already satisfied: dask in /usr/local/lib/python3.10/dist-packages (from ktext) (2023.8.1)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from ktext) (14.0.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from ktext) (10.1.0)
# Requirement already satisfied: textacy<=0.6.2 in /usr/local/lib/python3.10/dist-packages (from ktext) (0.6.2)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from ktext) (2.15.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from ktext) (2.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.21.0->ktext) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.21.0->ktext) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.21.0->ktext) (2024.1)
# Requirement already satisfied: cachetools>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from textacy<=0.6.2->ktext) (5.3.3)
# Requirement already satisfied: cytoolz>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from textacy<=0.6.2->ktext) (0.12.3)
# Requirement already satisfied: ftfy<5.0.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from textacy<=0.6.2->ktext) (4.4.3)
# Requirement already satisfied: ijson>=2.3 in /usr/local/lib/python3.10/dist-packages (from textacy<=0.6.2->ktext) (3.3.0)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.10/dist-packages (from textacy<=0.6.2->ktext) (3.3)
# Requirement already satisfied: pyemd>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from textacy<=0.6.2->ktext) (1.0.0)
# Requirement already satisfied: pyphen>=0.9.4 in /usr/local/lib/python3.10/dist-packages (from textacy<=0.6.2->ktext) (0.15.0)
# Requirement already satisfied: python-levenshtein>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from textacy<=0.6.2->ktext) (0.25.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from textacy<=0.6.2->ktext) (2.31.0)
# Requirement already satisfied: scikit-learn>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from textacy<=0.6.2->ktext) (1.2.2)
# Requirement already satisfied: spacy>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from textacy<=0.6.2->ktext) (3.7.4)
# Requirement already satisfied: tqdm>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from textacy<=0.6.2->ktext) (4.66.4)
# Requirement already satisfied: unidecode>=0.04.19 in /usr/local/lib/python3.10/dist-packages (from textacy<=0.6.2->ktext) (1.3.8)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask->ktext) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask->ktext) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask->ktext) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask->ktext) (24.0)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask->ktext) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask->ktext) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask->ktext) (7.1.0)
# Requirement already satisfied: ppft>=1.7.6.8 in /usr/local/lib/python3.10/dist-packages (from pathos->ktext) (1.7.6.8)
# Requirement already satisfied: dill>=0.3.8 in /usr/local/lib/python3.10/dist-packages (from pathos->ktext) (0.3.8)
# Requirement already satisfied: pox>=0.3.4 in /usr/local/lib/python3.10/dist-packages (from pathos->ktext) (0.3.4)
# Requirement already satisfied: multiprocess>=0.70.16 in /usr/local/lib/python3.10/dist-packages (from pathos->ktext) (0.70.16)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (67.7.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (4.12.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->ktext) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->ktext) (0.43.0)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.10/dist-packages (from ftfy<5.0.0,>=4.2.0->textacy<=0.6.2->ktext) (1.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy<5.0.0,>=4.2.0->textacy<=0.6.2->ktext) (0.2.13)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask->ktext) (3.19.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask->ktext) (1.0.0)
# Requirement already satisfied: Levenshtein==0.25.1 in /usr/local/lib/python3.10/dist-packages (from python-levenshtein>=0.12.0->textacy<=0.6.2->ktext) (0.25.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from Levenshtein==0.25.1->python-levenshtein>=0.12.0->textacy<=0.6.2->ktext) (3.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->textacy<=0.6.2->ktext) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->textacy<=0.6.2->ktext) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->textacy<=0.6.2->ktext) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->textacy<=0.6.2->ktext) (2024.6.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.17.0->textacy<=0.6.2->ktext) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.17.0->textacy<=0.6.2->ktext) (3.5.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.0->textacy<=0.6.2->ktext) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.0->textacy<=0.6.2->ktext) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.0->textacy<=0.6.2->ktext) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.0->textacy<=0.6.2->ktext) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.0->textacy<=0.6.2->ktext) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.0->textacy<=0.6.2->ktext) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.0->textacy<=0.6.2->ktext) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.0->textacy<=0.6.2->ktext) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.0->textacy<=0.6.2->ktext) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.0->textacy<=0.6.2->ktext) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.0->textacy<=0.6.2->ktext) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.0->textacy<=0.6.2->ktext) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.0->textacy<=0.6.2->ktext) (2.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.0->textacy<=0.6.2->ktext) (3.1.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.0->textacy<=0.6.2->ktext) (3.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->ktext) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->ktext) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->ktext) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->ktext) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->ktext) (3.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->ktext) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->ktext) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->ktext) (1.3.1)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy>=2.0.0->textacy<=0.6.2->ktext) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.0->textacy<=0.6.2->ktext) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.0->textacy<=0.6.2->ktext) (2.18.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.0.0->textacy<=0.6.2->ktext) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.0.0->textacy<=0.6.2->ktext) (0.1.5)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy>=2.0.0->textacy<=0.6.2->ktext) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow->ktext) (2.1.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib->ftfy<5.0.0,>=4.2.0->textacy<=0.6.2->ktext) (0.5.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=2.0.0->textacy<=0.6.2->ktext) (1.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->ktext) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->ktext) (3.2.2)

# %%
from ktext.preprocess import processor

# %%
# Initialize the processor with specific parameters
# keep_n: the maximum number of unique words to keep
# padding_maxlen: the maximum length of sequences to pad or truncate
english_pp = processor(keep_n=10407, padding_maxlen=7)

# Fit the processor on the training data and transform the data into vectors
# This step learns the vocabulary from the training data and converts the text into numerical vectors
english_train_vecs = english_pp.fit_transform(english_train)

# The result is a list of sequences where each sequence represents a processed and vectorized version of the input text
print(english_train_vecs)
# Out:
# WARNING:root:....tokenizing data
# /usr/local/lib/python3.10/dist-packages/multiprocess/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# WARNING:root:(1/2) done. 14 sec
# WARNING:root:....building corpus
# WARNING:root:(2/2) done. 0 sec
# WARNING:root:Finished parsing 43,369 documents.
# WARNING:root:...fit is finished, beginning transform
# WARNING:root:...padding data
# WARNING:root:done. 0 sec
# [[   0    0    2 ...   20  646    3]
#  [   2   11 1772 ...   52  415    3]
#  [   0    2   15 ...   43   23    3]
#  ...
#  [   0    2    9 ...   31  350    3]
#  [   2   30   10 ...   37  456    3]
#  [   0    0    2 ...   19  202    3]]

# %%
# Initialize the processor with specific parameters for French text data
# append_indicators: whether to add start and end indicators to the sequences
# keep_n: the maximum number of unique words to keep
# padding_maxlen: the maximum length of sequences to pad or truncate
# padding: whether padding is added 'pre' (at the beginning) or 'post' (at the end) of sequences
french_pp = processor(append_indicators=True, keep_n=17228, padding_maxlen=7, padding='post')

# Fit the processor on the French training data and transform the data into vectors
# This step learns the vocabulary from the training data and converts the text into numerical vectors
french_train_vecs = french_pp.fit_transform(french_train)
# Out:
# WARNING:root:....tokenizing data
# WARNING:root:(1/2) done. 13 sec
# WARNING:root:....building corpus
# WARNING:root:(2/2) done. 0 sec
# WARNING:root:Finished parsing 43,369 documents.
# WARNING:root:...fit is finished, beginning transform
# WARNING:root:...padding data
# WARNING:root:done. 0 sec

# %%
import dill as dpickle
import numpy as np

#save the perprocessor
with open('english_pp.dpkl', 'wb') as f:
  dpickle.dump(english_pp, f)

with open('french_pp.dpkl', 'wb') as f:
  dpickle.dump(french_pp, f)

#save the processed data

np.save('french_train_vecs.npy', french_train_vecs)
np.save('english_train_vecs.npy', english_train_vecs)

# %%
def load_decoder_inputs(decoder_np_vecs='french_train_vecs.npy'):
    # Load the vectorized title data from a .npy file
    vectorized_title = np.load(decoder_np_vecs)

    # Decoder input data: all rows and all columns except the last one
    decoder_input_data = vectorized_title[:, :-1]

    # Decoder target data: all rows and all columns except the first one
    decoder_target_data = vectorized_title[:, 1:]

    # Print the shapes of the input and target data
    print(f'Shape of decoder input: {decoder_input_data.shape}')
    print(f'Shape of decoder target: {decoder_target_data.shape}')
    return decoder_input_data, decoder_target_data


def load_encoder_inputs(encoder_np_vecs='english_train_vecs.npy'):
    # Load the vectorized body data from a .npy file
    vectorized_body = np.load(encoder_np_vecs)

    # Encoder input data is the entire loaded array
    encoder_input_data = vectorized_body

    # Document length is the number of columns in the array
    doc_length = encoder_input_data.shape[1]

    # Print the shape of the encoder input data
    print(f'Shape of encoder input: {encoder_input_data.shape}')

    return encoder_input_data, doc_length

# %%
def load_text_processor(fname='english_pp.dpkl'):
    # Load files from disk
    with open(fname, 'rb') as f:
        pp = dpickle.load(f)

    num_tokens = max(pp.id2token.keys()) + 1
    print(f'Size of vocabulary for {fname}: {num_tokens:,}')
    return num_tokens, pp

# %%
import dill as dpickle

# %%
num_encoder_tokens, english_pp = load_text_processor('english_pp.dpkl')
num_decoder_tokens, french_pp = load_text_processor('french_pp.dpkl')
# Out:
# Size of vocabulary for english_pp.dpkl: 6,773
# Size of vocabulary for french_pp.dpkl: 10,971

# %%
encoder_input_data, doc_length = load_encoder_inputs('english_train_vecs.npy')
decoder_input_data, decoder_target_data = load_decoder_inputs('french_train_vecs.npy')
# Out:
# Shape of encoder input: (43369, 7)
# Shape of decoder input: (43369, 6)
# Shape of decoder target: (43369, 6)

# %%
print('Original String: ', french_train[0])
print('After Pre-Processing: ', decoder_input_data[0])
# Out:
# Original String:  <start>Il pleuvait.<end>
# After Pre-Processing:  [   3    4   11 2247    2    5]

# %%
print('Original String: ', english_train[0])
print('After Pre-Processing: ', encoder_input_data[0])
# Out:
# Original String:  <start>It was raining.<end>
# After Pre-Processing:  [  0   0   2   9  20 646   3]

# %% [markdown]
# # **Define Model Architecture**

# %%
from keras.models import Model
from keras.layers import Input, LSTM, GRU, Dense, Embedding, BatchNormalization
from keras import optimizers

# %%
# Arbitrarily set latent dimension for embedding and hidden units
latent_dim = 300
doc_length = 100  # Assuming doc_length is predefined
num_encoder_tokens = 10000  # Assuming num_encoder_tokens is predefined
num_decoder_tokens = 10000  # Assuming num_decoder_tokens is predefined

#######################
#### Encoder Model ####
encoder_inputs = Input(shape=(doc_length,), name='Encoder-Input')

# Word embedding for encoder (ex: Issue Body)
x = Embedding(num_encoder_tokens, latent_dim, name='Body-Word-Embedding', mask_zero=False)(encoder_inputs)
x = BatchNormalization(name='Encoder-Batchnorm-1')(x)

# Intermediate GRU Layer (optional)
# x = GRU(Latent_dim, name='Encoder-Intermediate-GRU', return_sequences=True) (x)
# x = BatchNormalization (name='Encoder-Batchnorm-2')(x)

# We do not need the `encoder_output` just the hidden state.
_, state_h = GRU(latent_dim, return_state=True, name='Encoder-Last-GRU')(x)

# Encapsulate the encoder as a separate entity so we can just
# encode without decoding if we want to.
encoder_model = Model(inputs=encoder_inputs, outputs=state_h, name='Encoder-Model')

seq2seq_encoder_out = encoder_model(encoder_inputs)

#######################
#### Decoder Model ####
decoder_inputs = Input(shape=(None,), name='Decoder-Input')

# Word Embedding For Decoder (ex: Issue Titles)
dec_emb = Embedding(num_decoder_tokens, latent_dim, name='Decoder-Word-Embedding', mask_zero=False)(decoder_inputs)
dec_bn = BatchNormalization(name='Decoder-Batchnorm-1')(dec_emb)

# Set up the decoder, using decoder_state_input as initial state.
decoder_gru = GRU(latent_dim, return_state=True, return_sequences=True, name='Decoder-GRU')
decoder_gru_output, _ = decoder_gru(dec_bn, initial_state=seq2seq_encoder_out)
x = BatchNormalization(name='Decoder-Batchnorm-2')(decoder_gru_output)

# Dense Layer for prediction
decoder_dense = Dense(num_decoder_tokens, activation='softmax', name='Final-Output-Dense')
decoder_outputs = decoder_dense(x)

#######################
#### Seq2Seq Model ####

seq2seq_Model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

seq2seq_Model.compile(optimizer=optimizers.Nadam(learning_rate=0.001), loss='sparse_categorical_crossentropy')

# %%
seq2seq_Model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Decoder-Input (InputLayer)  [(None, None)]               0         []
#
#  Decoder-Word-Embedding (Em  (None, None, 300)            3000000   ['Decoder-Input[0][0]']
#  bedding)
#
#  Encoder-Input (InputLayer)  [(None, 100)]                0         []
#
#  Decoder-Batchnorm-1 (Batch  (None, None, 300)            1200      ['Decoder-Word-Embedding[0][0]
#  Normalization)                                                     ']
#
#  Encoder-Model (Functional)  (None, 300)                  3543000   ['Encoder-Input[0][0]']
#
#  Decoder-GRU (GRU)           [(None, None, 300),          541800    ['Decoder-Batchnorm-1[0][0]',
#                               (None, 300)]                           'Encoder-Model[0][0]']
#
#  Decoder-Batchnorm-2 (Batch  (None, None, 300)            1200      ['Decoder-GRU[0][0]']
#  Normalization)
#
#  Final-Output-Dense (Dense)  (None, None, 10000)          3010000   ['Decoder-Batchnorm-2[0][0]']
#
# ==================================================================================================
# Total params: 10097200 (38.52 MB)
# Trainable params: 10095400 (38.51 MB)
# Non-trainable params: 1800 (7.03 KB)
# __________________________________________________________________________________________________

# %%
from keras.callbacks import CSVLogger, ModelCheckpoint
# import numpy as np

# Script name base
script_name_base = 'tutorial_seq2seq'

# Callbacks
csv_logger = CSVLogger(f'{script_name_base}.log')
model_checkpoint = ModelCheckpoint(f'{script_name_base}.epoch{{epoch:02d}}-val{{val_loss:.5f}}.hdf5', save_best_only=True)

# Parameters
batch_size = 1200
epochs = 70

# # Ensure that the decoder target data has the correct shape
decoder_target_data_exp = np.expand_dims(decoder_target_data, axis=-1)

# Model fitting
history = seq2seq_Model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data_exp,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.12,
    callbacks=[csv_logger, model_checkpoint]
)
# Out:
# Epoch 1/70
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-0d558e7efce4> in <cell line: 19>()
#      17
#      18 # Model fitting
# ---> 19 history = seq2seq_Model.fit(
#      20     [encoder_input_data, decoder_input_data],
#      21     decoder_target_data_exp,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1401, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1384, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1373, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1150, in train_step
#         y_pred = self(x, training=True)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "model_5" is incompatible with the layer: expected shape=(None, 100), found shape=(None, 7)

# %%
del seq2seq_Model

# %%
seq2seq_Model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

seq2seq_Model.compile(optimizer = optimizers.Nadam(lr=0.001), loss='sparse_categorical_crossentropy')
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Nadam.

# %%
# Import necessary libraries
from keras.models import load_model

# Provide the correct path to the weights file
weights_file_path = 'tutorial_seq2seq.epoch23-val1.78077.hdf5'

# Check if the file exists
import os
if os.path.exists(weights_file_path):
    # Load the weights
    seq2seq_Model.load_weights(weights_file_path)
    print("Weights loaded successfully.")
else:
    print(f"Error: The file '{weights_file_path}' does not exist.")
# Out:
# Error: The file 'tutorial_seq2seq.epoch23-val1.78077.hdf5' does not exist.

# %%
def extract_encoder_model(model):
    """
    Extracts the encoder model from the given seq2seq model.

    Args:
        model (keras.Model): The seq2seq model containing the encoder.

    Returns:
        keras.Model: The encoder model.
    """
    encoder_model = model.get_layer('Encoder-Model')
    return encoder_model

def extract_decoder_model(model):
    """
    Extracts the decoder model from the given seq2seq model.

    Args:
        model (keras.Model): The seq2seq model containing the decoder.

    Returns:
        keras.Model: The decoder model.
    """
    # The latent dimension is the same throughout the architecture so we are going to
    # cheat and grab the latent dimension of the embedding because that is the same as what is
    # output from the decoder
    latent_dim = model.get_layer('Decoder-Word-Embedding').output_shape[-1]

    # Reconstruct the input into the decoder
    decoder_inputs = model.get_layer('Decoder-Input').input
    dec_emb = model.get_layer('Decoder-Word-Embedding')(decoder_inputs)
    dec_bn = model.get_layer('Decoder-Batchnorm-1')(dec_emb)

    # Instead of setting the initial state from the encoder and forgetting about it during
    # inference, we are not doing teacher forcing, so we will have to have a feedback loop from predictions
    # to the GRU, thus we define this input layer for the state so we can add this capability
    gru_inference_state_input = Input(shape=(latent_dim,), name='hidden_state_input')

    # We need to reuse the weights, which is why we are getting this.
    # If you inspect the decoder GRU that we created for training, it will take as input
    # 2 tensors:
    #   (1) the embedding Layer output for the teacher forcing
    #   (which will now be the last step's prediction, and will be _start_ on the first step)
    #   (2) the state, which we will initialize with the encoder on the first time step,
    #   and then grab the state after the first prediction and feed that back in again.
    gru_out, gru_state_out = model.get_layer('Decoder-GRU')([dec_bn, gru_inference_state_input])

    # Reconstruct dense Layers
    dec_bn2 = model.get_layer('Decoder-Batchnorm-2')(gru_out)
    dense_out = model.get_layer('Final-Output-Dense')(dec_bn2)
    decoder_model = Model([decoder_inputs, gru_inference_state_input], [dense_out, gru_state_out])

    return decoder_model

# %%
class Seq2Seq_Inference(object):
    def __init__(self, encoder_preprocessor, decoder_preprocessor, seq2seq_model):
        self.bp_english = encoder_preprocessor
        self.pp_french = decoder_preprocessor
        self.seq2seq_model = seq2seq_model
        self.encoder_model = extract_encoder_model(seq2seq_model)
        self.decoder_model = extract_decoder_model(seq2seq_model)
        self.default_max_len_french = self.pp_french.padding_maxlen
        self.nn = None
        self.rec_df = None

    def generate_french(self, raw_input_text, max_len_french=None):
        """
        Use the seq2seq model to generate a title given the body of an issue.
        Inputs:
            raw_input_text: str
                The body of the issue text as an input string.
            max_len_french: int (optional)
                The maximum length of the title the model will generate.
        Returns:
            tuple: A tuple containing the original body encoding and the generated French text.
        """
        if max_len_french is None:
            max_len_french = self.default_max_len_french

        # Get the encoder's features for the decoder
        raw_tokenized = self.bp_english.transform([raw_input_text])
        body_encoding = self.encoder_model.predict(raw_tokenized)

        # We want to save the encoder's embedding before it's updated by the decoder
        # because we can use that as an embedding for other tasks.
        original_body_encoding = body_encoding
        state_value = np.array(self.pp_french.token2id['_start_']).reshape(1, 1)

        decoded_sentence = []
        stop_condition = False
        while not stop_condition:
            preds, st = self.decoder_model.predict([state_value, body_encoding])

            # We are going to ignore indices (padding) and indices 1 (unknown)
            # Argmax will return the integer index corresponding to the prediction + 2 b/c we chopped off first two
            pred_idx = np.argmax(preds[:, :, 2:]) + 2

            # Retrieve word from index prediction
            pred_word_str = self.pp_french.id2token[pred_idx]
            if pred_word_str == '_end_' or len(decoded_sentence) >= max_len_french:
                stop_condition = True
                break

            decoded_sentence.append(pred_word_str)

            # Update the decoder for the next word
            body_encoding = st
            state_value = np.array(pred_idx).reshape(1, 1)

        return original_body_encoding, ' '.join(decoded_sentence)

    def print_example(self, i, english_text, french_text, threshold):
        if i:
            print("\n\n===========================================")
            print(f'=============== Example # {i} =============\n')

        print(f"English Text:\n {english_text} \n")

        if french_text:
            print(f"Original French text: \n {french_text}")

        emb, gen_french = self.generate_french(english_text)
        print("\n****** Machine Generated Title (Prediction) ******: \n", gen_french)

        if self.nn:
            # Return neighbors and distances
            n, d = self.nn.get_nns_by_vector(emb.flatten(), n=4, include_distances=True)

            if min(d) <= threshold:
                cols = ['French', 'English']
                dfcopy = self.rec_df.iloc[n][cols].copy(deep=True)
                dfcopy['dist'] = d
                similar_issues_df = dfcopy.query(f'dist <= {threshold}')

                display(similar_issues_df)

    def demo_model_predictions(self, n, df, threshold=1):
        # Extract body and title from DF
        english_text_list = df['English words/sentences'].tolist()
        french_text_list = df['French words/sentences'].tolist()

        demo_list = np.random.randint(low=0, high=len(english_text_list), size=n)

        for i in demo_list:
            self.print_example(i, english_text=english_text_list[i], french_text=french_text_list[i], threshold=threshold)

# %%
# Instantiate Seq2Seq_Inference class
seq2seq_inf = Seq2Seq_Inference(encoder_preprocessor=english_pp, decoder_preprocessor=french_pp, seq2seq_model=seq2seq_Model)

# %%
# Call the demo_model_predictions method to display predictions on random rows of the holdout set
seq2seq_inf.demo_model_predictions(n=5, df=test)
# Out:
# ===========================================
# =============== Example # 2715 =============
#
# English Text:
#  I'm soaked to the bone.
#
# Original French text:
#  Je suis trempé jusqu'à l'os.
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
#
# ****** Machine Generated Title (Prediction) ******:
#  dodo processus impatients tatouage liberte devenu legal
#
#
# ===========================================
# =============== Example # 7759 =============
#
# English Text:
#  I went over the report.
#
# Original French text:
#  J'ai parcouru le rapport.
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
#
# ****** Machine Generated Title (Prediction) ******:
#  voudrait sacrifices assister taquiner eloigna echouera indescriptible
#
#
# ===========================================
# =============== Example # 226 =============
#
# English Text:
#  He's too drunk.
#
# Original French text:
#  Il est trop saoul.
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
#
# ****** Machine Generated Title (Prediction) ******:
#  mobilier ballon talentueuse dyslexique frappez passames souhait
#
#
# ===========================================
# =============== Example # 10164 =============
#
# English Text:
#  You are drunk!
#
# Original French text:
#  Tu es saoul !
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
#
# ****** Machine Generated Title (Prediction) ******:
#  decue repliez autorisera acceptons scandaleusement scandaleusement montons
#
#
# ===========================================
# =============== Example # 10629 =============
#
# English Text:
#  He is a dramatist.
#
# Original French text:
#  Il est dramaturge.
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
#
# ****** Machine Generated Title (Prediction) ******:
#  voudrait sacrifices assister taquiner eloigna echouera indescriptible

# %%
# !pip install transformers torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 44.5 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105

# %% [markdown]
# # **Machine Learning Model**
#
# **MarianMT Model:**
# - The MarianMTModel used in this script is a machine translation model based on the Transformer architecture, developed by the Marian team at the University of Edinburgh.
#
# - These models are pre-trained on large parallel corpora of text in multiple languages and can translate between various language pairs.
#
# - The specific models used here are Helsinki-NLP/opus-mt-fr-en for French to English translation and Helsinki-NLP/opus-mt-en-ur for English to Urdu translation. These models are available through the Hugging Face Model Hub and have been trained on large datasets to perform high-quality translations.
#
# **How It Works**
# 1. **Input Handling:** The script takes user input to determine the translation direction and the text to be translated.
#
# 2. **Preprocessing:** The text is tokenized into a format suitable for the model using MarianTokenizer.
#
# 3. **Translation:** The model generates translated text in the target language.
# Postprocessing: The tokenized output is decoded back into a human-readable string.
#
# 4. **Output:** The translated text is displayed to the user.

# %%
from transformers import MarianMTModel, MarianTokenizer

# French to English
def translate_fr_en(text):
    model_name = 'Helsinki-NLP/opus-mt-fr-en'
    tokenizer = MarianTokenizer.from_pretrained(model_name)
    model = MarianMTModel.from_pretrained(model_name)
    translated = model.generate(**tokenizer(text, return_tensors="pt", padding=True))
    return [tokenizer.decode(t, skip_special_tokens=True) for t in translated][0]

# English to Urdu
def translate_en_ur(text):
    model_name = 'Helsinki-NLP/opus-mt-en-ur'
    tokenizer = MarianTokenizer.from_pretrained(model_name)
    model = MarianMTModel.from_pretrained(model_name)
    translated = model.generate(**tokenizer(text, return_tensors="pt", padding=True))
    return [tokenizer.decode(t, skip_special_tokens=True) for t in translated][0]

# %%
def user_interface():
    print("Press 1 for French to English translation")
    print("Press 2 for English to Urdu translation")
    choice = input("Enter your choice: ")

    if choice == '1':
        text = input("Enter French text: ")
        translation = translate_fr_en(text)
        print("Translation:", translation)
    elif choice == '2':
        text = input("Enter English text: ")
        translation = translate_en_ur(text)
        print("Translation:", translation)
    else:
        print("Invalid choice. Please enter 1 or 2.")

# %%
if __name__ == "__main__":
    user_interface()
# Out:
# Press 1 for French to English translation
# Press 2 for English to Urdu translation
# Enter your choice: 2
# Enter English text: Hi we are mustafa and ammad
# Translation: خوش آمدید ہم کر رہے ہیں وراور کر رہے ہیں
